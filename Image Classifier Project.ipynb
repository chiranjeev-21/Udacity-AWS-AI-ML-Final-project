# %% [markdown]
# # Developing an AI application
#
# Going forward, AI algorithms will be incorporated into more and more everyday applications. For example, you might want to include an image classifier in a smart phone app. To do this, you'd use a deep learning model trained on hundreds of thousands of images as part of the overall application architecture. A large part of software development in the future will be using these types of models as common parts of applications.
#
# In this project, you'll train an image classifier to recognize different species of flowers. You can imagine using something like this in a phone app that tells you the name of the flower your camera is looking at. In practice you'd train this classifier, then export it for use in your application. We'll be using [this dataset](http://www.robots.ox.ac.uk/~vgg/data/flowers/102/index.html) of 102 flower categories, you can see a few examples below.
#
# <img src='assets/Flowers.png' width=500px>
#
# The project is broken down into multiple steps:
#
# * Load and preprocess the image dataset
# * Train the image classifier on your dataset
# * Use the trained classifier to predict image content
#
# We'll lead you through each part which you'll implement in Python.
#
# When you've completed this project, you'll have an application that can be trained on any set of labeled images. Here your network will be learning about flowers and end up as a command line application. But, what you do with your new skills depends on your imagination and effort in building a dataset. For example, imagine an app where you take a picture of a car, it tells you what the make and model is, then looks up information about it. Go build your own dataset and make something new.
#
# First up is importing the packages you'll need. It's good practice to keep all the imports at the beginning of your code. As you work through this notebook and find you need to import a package, make sure to add the import up here.

# %%
# Imports here
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import torch
from torch import nn
from torch import tensor
from torch import optim
import torch.nn.functional as F
from torch.autograd import Variable
from torchvision import datasets, transforms
import torchvision.models as models
import argparse
from collections import OrderedDict
import json
import PIL
import seaborn as sns
from PIL import Image
import time

# %% [markdown]
# ## Load the data
#
# Here you'll use `torchvision` to load the data ([documentation](http://pytorch.org/docs/0.3.0/torchvision/index.html)). The data should be included alongside this notebook, otherwise you can [download it here](https://s3.amazonaws.com/content.udacity-data.com/nd089/flower_data.tar.gz). The dataset is split into three parts, training, validation, and testing. For the training, you'll want to apply transformations such as random scaling, cropping, and flipping. This will help the network generalize leading to better performance. You'll also need to make sure the input data is resized to 224x224 pixels as required by the pre-trained networks.
#
# The validation and testing sets are used to measure the model's performance on data it hasn't seen yet. For this you don't want any scaling or rotation transformations, but you'll need to resize then crop the images to the appropriate size.
#
# The pre-trained networks you'll use were trained on the ImageNet dataset where each color channel was normalized separately. For all three sets you'll need to normalize the means and standard deviations of the images to what the network expects. For the means, it's `[0.485, 0.456, 0.406]` and for the standard deviations `[0.229, 0.224, 0.225]`, calculated from the ImageNet images.  These values will shift each color channel to be centered at 0 and range from -1 to 1.

# %%
data_dir = 'flowers'
train_dir = data_dir + '/train'
valid_dir = data_dir + '/valid'
test_dir = data_dir + '/test'

# %%
# TODO: Define your transforms for the training, validation, and testing sets
data_transforms = { 
    'train': transforms.Compose([
        transforms.RandomResizedCrop(size=224),
        transforms.RandomHorizontalFlip(),
        transforms.ToTensor(),
        transforms.Normalize([0.485,0.456,0.406],
                             [0.229,0.224,0.225])
    ]),
    'valid': transforms.Compose([
        transforms.Resize(size=256),
        transforms.CenterCrop(size=224),
        transforms.ToTensor(),
        transforms.Normalize([0.485,0.456,0.406],
                             [0.229,0.224,0.225])
    ]),
    'test': transforms.Compose([
        transforms.Resize(size=256),
        transforms.CenterCrop(size=224),
        transforms.ToTensor(),
        transforms.Normalize([0.485,0.456,0.406],
                             [0.229,0.224,0.225])
    ])
}

# TODO: Load the datasets with ImageFolder
image_datasets = {
    'train': datasets.ImageFolder(train_dir, transform=data_transforms['train']),
    'valid': datasets.ImageFolder(valid_dir, transform=data_transforms['valid']),
    'test': datasets.ImageFolder(test_dir, transform=data_transforms['test'])
}

# TODO: Using the image datasets and the trainforms, define the dataloaders

train_loader = torch.utils.data.DataLoader(image_datasets['train'], batch_size=64, shuffle=True)
validation_loader = torch.utils.data.DataLoader(image_datasets['valid'], batch_size =64,shuffle = True)
test_loader = torch.utils.data.DataLoader(image_datasets['test'], batch_size = 64, shuffle = True)

# %% [markdown]
# ### Label mapping
#
# You'll also need to load in a mapping from category label to category name. You can find this in the file `cat_to_name.json`. It's a JSON object which you can read in with the [`json` module](https://docs.python.org/2/library/json.html). This will give you a dictionary mapping the integer encoded categories to the actual names of the flowers.

# %%
import json

with open('cat_to_name.json', 'r') as f:
    cat_to_name = json.load(f)

# %% [markdown]
# # Building and training the classifier
#
# Now that the data is ready, it's time to build and train the classifier. As usual, you should use one of the pretrained models from `torchvision.models` to get the image features. Build and train a new feed-forward classifier using those features.
#
# We're going to leave this part up to you. Refer to [the rubric](https://review.udacity.com/#!/rubrics/1663/view) for guidance on successfully completing this section. Things you'll need to do:
#
# * Load a [pre-trained network](http://pytorch.org/docs/master/torchvision/models.html) (If you need a starting point, the VGG networks work great and are straightforward to use)
# * Define a new, untrained feed-forward network as a classifier, using ReLU activations and dropout
# * Train the classifier layers using backpropagation using the pre-trained network to get the features
# * Track the loss and accuracy on the validation set to determine the best hyperparameters
#
# We've left a cell open for you below, but use as many as you need. Our advice is to break the problem up into smaller parts you can run separately. Check that each part is doing what you expect, then move on to the next. You'll likely find that as you work through each part, you'll need to go back and modify your previous code. This is totally normal!
#
# When training make sure you're updating only the weights of the feed-forward network. You should be able to get the validation accuracy above 70% if you build everything right. Make sure to try different hyperparameters (learning rate, units in the classifier, epochs, etc) to find the best model. Save those hyperparameters to use as default values in the next part of the project.
#
# One last important tip if you're using the workspace to run your code: To avoid having your workspace disconnect during the long-running tasks in this notebook, please read in the earlier page in this lesson called Intro to
# GPU Workspaces about Keeping Your Session Active. You'll want to include code from the workspace_utils.py module.
#
# <font color='red'>**Note for Workspace users:** If your network is over 1 GB when saved as a checkpoint, there might be issues with saving backups in your workspace. Typically this happens with wide dense layers after the convolutional layers. If your saved checkpoint is larger than 1 GB (you can open a terminal and check with `ls -lh`), you should reduce the size of your hidden layers and train again.</font>

# %%
# TODO: Build and train your network
model = models.vgg16(pretrained=True)

#When a model is loaded in PyTorch, all its parameters have their ‘requires_grad‘ field set to true by default. 
#That means each and every change to the parameter values will be stored in order to be used in the back propagation graph 
#used for training. This increases memory requirements. So,
#since most of the parameters in our pre-trained model are already trained for us, we reset the requires_grad field to false.

#to freeze part of the convolutional part of vgg16 model and train the rest
for param in model.parameters():
    param.requires_grad = False
        
#Then we replace the final layer of the vgg16 model by a small set of Sequential layers. 
#The inputs to the last fully connected layer of vgg16 is fed to a Linear layer, 
#which are then fed into ReLU (rectified linear unit) and Dropout layers.


#Used OrderedDict to preserve the order in which the keys are inserted
from collections import OrderedDict

classifier = nn.Sequential(OrderedDict([
            ('inputs', nn.Linear(25088, 120)), #hidden layer 1 sets output to 120
            ('relu1', nn.ReLU()),
            ('dropout',nn.Dropout(0.5)), #could use a different droupout probability,but 0.5 usually works well
            ('hidden_layer1', nn.Linear(120, 90)), #hidden layer 2 output to 90
            ('relu2',nn.ReLU()),
            ('hidden_layer2',nn.Linear(90,70)), #hidden layer 3 output to 70
            ('relu3',nn.ReLU()),
            ('hidden_layer3',nn.Linear(70,102)),#output size = 102
            ('output', nn.LogSoftmax(dim=1))]))# For using NLLLoss()
   
model.classifier = classifier
        
#Since we will be doing the training on a GPU, we get the model ready for GPU.

# Convert model to be used on GPU
if torch.cuda.is_available():
    model.cuda()

#define the criterion and the optimizer to be used for training.
#Negative Loss Likelihood function(NLLLoss()) as it can be used for classifying multiple classes.
#Adam is one the most popular optimizers because it can adapt the learning rate for each parameter individually.

criterion = nn.NLLLoss()
optimizer = optim.Adam(model.classifier.parameters(), lr=0.001)
# Out:
# Downloading: "https://download.pytorch.org/models/vgg16-397923af.pth" to /root/.torch/models/vgg16-397923af.pth
# 100%|██████████| 553433881/553433881 [00:04<00:00, 112336470.64it/s]

# %%
epochs=10
for epoch in range(epochs):
    print("Epoch: {}/{}".format(epoch+1, epochs))
     
# tell the model that you are training . So effectively layers like dropout, batchnorm etc,
#which behave different on the train and test procedures know what is going on and hence can behave accordingly.
# Set to training mode    
    # Set to training mode
    model.train()
     
    # Loss and Accuracy within the epoch
    train_loss = 0.0
    train_acc = 0.0
     
    valid_loss = 0.0
    valid_acc = 0.0
 
    for i, (inputs, labels) in enumerate(train_loader):
 
        inputs = inputs.to('cuda')
        labels = labels.to('cuda')
         
        # Clean existing gradients
        optimizer.zero_grad()
         
        # Forward pass - compute outputs on input data using the model
        outputs = model(inputs)
         
        # Compute loss
        loss = criterion(outputs, labels)
         
        # Backpropagate the gradients
        loss.backward()
         
        # Update the parameters
        optimizer.step()
         
        # Compute the total loss for the batch and add it to train_loss
        train_loss += loss.item() * inputs.size(0)
         
        # Compute the accuracy
        ret, predictions = torch.max(outputs.data, 1)
        correct_counts = predictions.eq(labels.data.view_as(predictions))
         
        # Convert correct_counts to float and then compute the mean
        acc = torch.mean(correct_counts.type(torch.FloatTensor))
         
        # Compute total accuracy in the whole batch and add to train_acc
        train_acc += acc.item() * inputs.size(0)
         
        print("Batch no: {:03d}, Loss on trainig: {:.4f}, Accuracy: {:.4f}".format(i, loss.item(), acc.item()))
# Out:
# Epoch: 1/10
# Batch no: 000, Loss on trainig: 4.6246, Accuracy: 0.0000
# Batch no: 001, Loss on trainig: 4.6213, Accuracy: 0.0312
# Batch no: 002, Loss on trainig: 4.6969, Accuracy: 0.0156
# Batch no: 003, Loss on trainig: 4.5503, Accuracy: 0.0469
# Batch no: 004, Loss on trainig: 4.6038, Accuracy: 0.0000
# Batch no: 005, Loss on trainig: 4.7345, Accuracy: 0.0312
# Batch no: 006, Loss on trainig: 4.5392, Accuracy: 0.0469
# Batch no: 007, Loss on trainig: 4.5888, Accuracy: 0.0312
# Batch no: 008, Loss on trainig: 4.5188, Accuracy: 0.0938
# Batch no: 009, Loss on trainig: 4.6870, Accuracy: 0.0156
# Batch no: 010, Loss on trainig: 4.6492, Accuracy: 0.0312
# Batch no: 011, Loss on trainig: 4.5633, Accuracy: 0.0156
# Batch no: 012, Loss on trainig: 4.6325, Accuracy: 0.0000
# Batch no: 013, Loss on trainig: 4.4812, Accuracy: 0.0625
# Batch no: 014, Loss on trainig: 4.4868, Accuracy: 0.0469
# Batch no: 015, Loss on trainig: 4.5596, Accuracy: 0.0625
# Batch no: 016, Loss on trainig: 4.4977, Accuracy: 0.0469
# Batch no: 017, Loss on trainig: 4.4349, Accuracy: 0.0625
# Batch no: 018, Loss on trainig: 4.4267, Accuracy: 0.0312
# Batch no: 019, Loss on trainig: 4.5520, Accuracy: 0.0156
# Batch no: 020, Loss on trainig: 4.4263, Accuracy: 0.0781
# Batch no: 021, Loss on trainig: 4.4129, Accuracy: 0.0000
# Batch no: 022, Loss on trainig: 4.4088, Accuracy: 0.1406
# Batch no: 023, Loss on trainig: 4.3566, Accuracy: 0.0469
# Batch no: 024, Loss on trainig: 4.5650, Accuracy: 0.0625
# Batch no: 025, Loss on trainig: 4.5021, Accuracy: 0.0625
# Batch no: 026, Loss on trainig: 4.4980, Accuracy: 0.0312
# Batch no: 027, Loss on trainig: 4.3246, Accuracy: 0.0625
# Batch no: 028, Loss on trainig: 4.2655, Accuracy: 0.1250
# Batch no: 029, Loss on trainig: 4.4412, Accuracy: 0.0469
# Batch no: 030, Loss on trainig: 4.3850, Accuracy: 0.0625
# Batch no: 031, Loss on trainig: 4.1484, Accuracy: 0.1406
# Batch no: 032, Loss on trainig: 4.0937, Accuracy: 0.0781
# Batch no: 033, Loss on trainig: 4.3901, Accuracy: 0.0781
# Batch no: 034, Loss on trainig: 4.3448, Accuracy: 0.0625
# Batch no: 035, Loss on trainig: 4.1034, Accuracy: 0.1719
# Batch no: 036, Loss on trainig: 4.2175, Accuracy: 0.0938
# Batch no: 037, Loss on trainig: 4.0877, Accuracy: 0.1250
# Batch no: 038, Loss on trainig: 4.0590, Accuracy: 0.1562
# Batch no: 039, Loss on trainig: 3.9485, Accuracy: 0.1250
# Batch no: 040, Loss on trainig: 4.1639, Accuracy: 0.0781
# Batch no: 041, Loss on trainig: 4.1551, Accuracy: 0.0938
# Batch no: 042, Loss on trainig: 4.1712, Accuracy: 0.0938
# Batch no: 043, Loss on trainig: 4.2248, Accuracy: 0.0312
# Batch no: 044, Loss on trainig: 3.9658, Accuracy: 0.1250
# Batch no: 045, Loss on trainig: 4.0273, Accuracy: 0.1094
# Batch no: 046, Loss on trainig: 3.9476, Accuracy: 0.2188
# Batch no: 047, Loss on trainig: 4.1849, Accuracy: 0.1562
# Batch no: 048, Loss on trainig: 4.0124, Accuracy: 0.1094
# Batch no: 049, Loss on trainig: 3.8947, Accuracy: 0.2031
# Batch no: 050, Loss on trainig: 4.2283, Accuracy: 0.0625
# Batch no: 051, Loss on trainig: 3.9802, Accuracy: 0.1094
# Batch no: 052, Loss on trainig: 4.1679, Accuracy: 0.0625
# Batch no: 053, Loss on trainig: 3.9800, Accuracy: 0.1094
# Batch no: 054, Loss on trainig: 4.0422, Accuracy: 0.0781
# Batch no: 055, Loss on trainig: 3.7752, Accuracy: 0.1719
# Batch no: 056, Loss on trainig: 3.9344, Accuracy: 0.1562
# Batch no: 057, Loss on trainig: 3.9449, Accuracy: 0.1406
# Batch no: 058, Loss on trainig: 3.8439, Accuracy: 0.1406
# Batch no: 059, Loss on trainig: 3.8507, Accuracy: 0.1719
# Batch no: 060, Loss on trainig: 3.9424, Accuracy: 0.1094
# Batch no: 061, Loss on trainig: 3.8114, Accuracy: 0.1406
# Batch no: 062, Loss on trainig: 3.5673, Accuracy: 0.2188
# Batch no: 063, Loss on trainig: 3.7514, Accuracy: 0.1875
# Batch no: 064, Loss on trainig: 3.7685, Accuracy: 0.1719
# Batch no: 065, Loss on trainig: 3.9144, Accuracy: 0.1250
# Batch no: 066, Loss on trainig: 3.6636, Accuracy: 0.1719
# Batch no: 067, Loss on trainig: 3.9042, Accuracy: 0.1250
# Batch no: 068, Loss on trainig: 3.5511, Accuracy: 0.1875
# Batch no: 069, Loss on trainig: 3.9912, Accuracy: 0.0625
# Batch no: 070, Loss on trainig: 3.5862, Accuracy: 0.2344
# Batch no: 071, Loss on trainig: 3.3975, Accuracy: 0.2031
# Batch no: 072, Loss on trainig: 3.6449, Accuracy: 0.1719
# Batch no: 073, Loss on trainig: 3.8964, Accuracy: 0.1250
# Batch no: 074, Loss on trainig: 3.5813, Accuracy: 0.1719
# Batch no: 075, Loss on trainig: 3.5857, Accuracy: 0.2188
# Batch no: 076, Loss on trainig: 3.6273, Accuracy: 0.1406
# Batch no: 077, Loss on trainig: 3.7075, Accuracy: 0.1562
# Batch no: 078, Loss on trainig: 3.3523, Accuracy: 0.2500
# Batch no: 079, Loss on trainig: 3.5592, Accuracy: 0.1406
# Batch no: 080, Loss on trainig: 3.5033, Accuracy: 0.2188
# Batch no: 081, Loss on trainig: 3.4131, Accuracy: 0.2656
# Batch no: 082, Loss on trainig: 3.5777, Accuracy: 0.1406
# Batch no: 083, Loss on trainig: 3.7701, Accuracy: 0.0938
# Batch no: 084, Loss on trainig: 3.5737, Accuracy: 0.1562
# Batch no: 085, Loss on trainig: 3.5436, Accuracy: 0.1094
# Batch no: 086, Loss on trainig: 3.3791, Accuracy: 0.1562
# Batch no: 087, Loss on trainig: 3.1941, Accuracy: 0.1875
# Batch no: 088, Loss on trainig: 3.3606, Accuracy: 0.2031
# Batch no: 089, Loss on trainig: 3.3274, Accuracy: 0.2500
# Batch no: 090, Loss on trainig: 3.3982, Accuracy: 0.1875
# Batch no: 091, Loss on trainig: 3.4000, Accuracy: 0.2344
# Batch no: 092, Loss on trainig: 3.0566, Accuracy: 0.2812
# Batch no: 093, Loss on trainig: 3.2278, Accuracy: 0.2031
# Batch no: 094, Loss on trainig: 3.4569, Accuracy: 0.1719
# Batch no: 095, Loss on trainig: 3.2710, Accuracy: 0.2031
# Batch no: 096, Loss on trainig: 3.2229, Accuracy: 0.2500
# Batch no: 097, Loss on trainig: 2.9404, Accuracy: 0.2812
# Batch no: 098, Loss on trainig: 2.8915, Accuracy: 0.2344
# Batch no: 099, Loss on trainig: 3.3221, Accuracy: 0.2188
# Batch no: 100, Loss on trainig: 3.4545, Accuracy: 0.1875
# Batch no: 101, Loss on trainig: 3.5353, Accuracy: 0.2500
# Batch no: 102, Loss on trainig: 3.0816, Accuracy: 0.2083
# Epoch: 2/10
# Batch no: 000, Loss on trainig: 2.9849, Accuracy: 0.2969
# Batch no: 001, Loss on trainig: 3.1424, Accuracy: 0.2344
# Batch no: 002, Loss on trainig: 3.1287, Accuracy: 0.2344
# Batch no: 003, Loss on trainig: 3.0749, Accuracy: 0.2969
# Batch no: 004, Loss on trainig: 3.2682, Accuracy: 0.2812
# Batch no: 005, Loss on trainig: 3.0590, Accuracy: 0.2500
# Batch no: 006, Loss on trainig: 3.4827, Accuracy: 0.1875
# Batch no: 007, Loss on trainig: 3.0863, Accuracy: 0.2031
# Batch no: 008, Loss on trainig: 2.9246, Accuracy: 0.2031
# Batch no: 009, Loss on trainig: 2.9456, Accuracy: 0.2812
# Batch no: 010, Loss on trainig: 2.7354, Accuracy: 0.2812
# Batch no: 011, Loss on trainig: 2.9614, Accuracy: 0.2500
# Batch no: 012, Loss on trainig: 3.1677, Accuracy: 0.2500
# Batch no: 013, Loss on trainig: 3.4792, Accuracy: 0.1875
# Batch no: 014, Loss on trainig: 2.9466, Accuracy: 0.2969
# Batch no: 015, Loss on trainig: 3.0108, Accuracy: 0.2500
# Batch no: 016, Loss on trainig: 2.6005, Accuracy: 0.3906
# Batch no: 017, Loss on trainig: 2.6986, Accuracy: 0.3750
# Batch no: 018, Loss on trainig: 3.0915, Accuracy: 0.2031
# Batch no: 019, Loss on trainig: 2.9079, Accuracy: 0.3594
# Batch no: 020, Loss on trainig: 2.7676, Accuracy: 0.3125
# Batch no: 021, Loss on trainig: 2.7508, Accuracy: 0.2344
# Batch no: 022, Loss on trainig: 2.9497, Accuracy: 0.2500
# Batch no: 023, Loss on trainig: 3.2190, Accuracy: 0.1875
# Batch no: 024, Loss on trainig: 2.7166, Accuracy: 0.3281
# Batch no: 025, Loss on trainig: 2.5978, Accuracy: 0.3750
# Batch no: 026, Loss on trainig: 2.9427, Accuracy: 0.2812
# Batch no: 027, Loss on trainig: 2.6645, Accuracy: 0.3594
# Batch no: 028, Loss on trainig: 3.0814, Accuracy: 0.2188
# Batch no: 029, Loss on trainig: 2.8444, Accuracy: 0.2188
# Batch no: 030, Loss on trainig: 2.6813, Accuracy: 0.3125
# Batch no: 031, Loss on trainig: 2.7817, Accuracy: 0.2344
# Batch no: 032, Loss on trainig: 2.2987, Accuracy: 0.3906
# Batch no: 033, Loss on trainig: 2.5388, Accuracy: 0.3125
# Batch no: 034, Loss on trainig: 2.8984, Accuracy: 0.2344
# Batch no: 035, Loss on trainig: 2.6793, Accuracy: 0.3281
# Batch no: 036, Loss on trainig: 2.8338, Accuracy: 0.2812
# Batch no: 037, Loss on trainig: 2.7586, Accuracy: 0.2656
# Batch no: 038, Loss on trainig: 3.0673, Accuracy: 0.2500
# Batch no: 039, Loss on trainig: 2.3434, Accuracy: 0.4375
# Batch no: 040, Loss on trainig: 2.9112, Accuracy: 0.2656
# Batch no: 041, Loss on trainig: 2.8240, Accuracy: 0.2344
# Batch no: 042, Loss on trainig: 2.8555, Accuracy: 0.2812
# Batch no: 043, Loss on trainig: 2.7868, Accuracy: 0.2656
# Batch no: 044, Loss on trainig: 2.9058, Accuracy: 0.2188
# Batch no: 045, Loss on trainig: 2.6761, Accuracy: 0.3438
# Batch no: 046, Loss on trainig: 2.9959, Accuracy: 0.2969
# Batch no: 047, Loss on trainig: 2.7937, Accuracy: 0.2812
# Batch no: 048, Loss on trainig: 2.5978, Accuracy: 0.3750
# Batch no: 049, Loss on trainig: 2.6922, Accuracy: 0.3125
# Batch no: 050, Loss on trainig: 2.8645, Accuracy: 0.2656
# Batch no: 051, Loss on trainig: 2.8745, Accuracy: 0.2656
# Batch no: 052, Loss on trainig: 3.1587, Accuracy: 0.2031
# Batch no: 053, Loss on trainig: 2.8088, Accuracy: 0.3125
# Batch no: 054, Loss on trainig: 2.9011, Accuracy: 0.2656
# Batch no: 055, Loss on trainig: 2.4356, Accuracy: 0.3281
# Batch no: 056, Loss on trainig: 2.5776, Accuracy: 0.4062
# Batch no: 057, Loss on trainig: 2.6557, Accuracy: 0.2969
# Batch no: 058, Loss on trainig: 2.5145, Accuracy: 0.3125
# Batch no: 059, Loss on trainig: 2.4527, Accuracy: 0.3594
# Batch no: 060, Loss on trainig: 2.7536, Accuracy: 0.3125
# Batch no: 061, Loss on trainig: 2.6977, Accuracy: 0.3125
# Batch no: 062, Loss on trainig: 2.3659, Accuracy: 0.3125
# Batch no: 063, Loss on trainig: 2.5337, Accuracy: 0.3594
# Batch no: 064, Loss on trainig: 2.5115, Accuracy: 0.3594
# Batch no: 065, Loss on trainig: 2.4691, Accuracy: 0.2969
# Batch no: 066, Loss on trainig: 2.6524, Accuracy: 0.2812
# Batch no: 067, Loss on trainig: 2.6899, Accuracy: 0.2812
# Batch no: 068, Loss on trainig: 2.5293, Accuracy: 0.3438
# Batch no: 069, Loss on trainig: 2.3831, Accuracy: 0.4062
# Batch no: 070, Loss on trainig: 2.5137, Accuracy: 0.2812
# Batch no: 071, Loss on trainig: 2.2950, Accuracy: 0.3281
# Batch no: 072, Loss on trainig: 2.1225, Accuracy: 0.4062
# Batch no: 073, Loss on trainig: 2.7349, Accuracy: 0.2500
# Batch no: 074, Loss on trainig: 2.6741, Accuracy: 0.3750
# Batch no: 075, Loss on trainig: 2.8797, Accuracy: 0.3125
# Batch no: 076, Loss on trainig: 2.6413, Accuracy: 0.3438
# Batch no: 077, Loss on trainig: 2.4440, Accuracy: 0.3594
# Batch no: 078, Loss on trainig: 2.2847, Accuracy: 0.4219
# Batch no: 079, Loss on trainig: 2.6278, Accuracy: 0.3438
# Batch no: 080, Loss on trainig: 2.8692, Accuracy: 0.2656
# Batch no: 081, Loss on trainig: 2.4823, Accuracy: 0.3594
# Batch no: 082, Loss on trainig: 2.5563, Accuracy: 0.3750
# Batch no: 083, Loss on trainig: 2.4930, Accuracy: 0.3281
# Batch no: 084, Loss on trainig: 2.7769, Accuracy: 0.2969
# Batch no: 085, Loss on trainig: 2.2458, Accuracy: 0.3750
# Batch no: 086, Loss on trainig: 2.5793, Accuracy: 0.3281
# Batch no: 087, Loss on trainig: 2.9399, Accuracy: 0.2344
# Batch no: 088, Loss on trainig: 2.5432, Accuracy: 0.3906
# Batch no: 089, Loss on trainig: 2.6579, Accuracy: 0.3281
# Batch no: 090, Loss on trainig: 2.2317, Accuracy: 0.4844
# Batch no: 091, Loss on trainig: 2.8079, Accuracy: 0.2656
# Batch no: 092, Loss on trainig: 2.3035, Accuracy: 0.4375
# Batch no: 093, Loss on trainig: 2.2624, Accuracy: 0.4062
# Batch no: 094, Loss on trainig: 2.3644, Accuracy: 0.3906
# Batch no: 095, Loss on trainig: 2.0077, Accuracy: 0.4219
# Batch no: 096, Loss on trainig: 2.5535, Accuracy: 0.2344
# Batch no: 097, Loss on trainig: 2.4563, Accuracy: 0.3281
# Batch no: 098, Loss on trainig: 2.6663, Accuracy: 0.3125
# Batch no: 099, Loss on trainig: 2.1972, Accuracy: 0.3906
# Batch no: 100, Loss on trainig: 2.2093, Accuracy: 0.4375
# Batch no: 101, Loss on trainig: 2.2189, Accuracy: 0.4219
# Batch no: 102, Loss on trainig: 2.0156, Accuracy: 0.4167
# Epoch: 3/10
# Batch no: 000, Loss on trainig: 2.4749, Accuracy: 0.2812
# Batch no: 001, Loss on trainig: 2.3265, Accuracy: 0.4688
# Batch no: 002, Loss on trainig: 2.0833, Accuracy: 0.4062
# Batch no: 003, Loss on trainig: 2.6488, Accuracy: 0.3438
# Batch no: 004, Loss on trainig: 2.2368, Accuracy: 0.3281
# Batch no: 005, Loss on trainig: 2.2907, Accuracy: 0.4062
# Batch no: 006, Loss on trainig: 2.4148, Accuracy: 0.3906
# Batch no: 007, Loss on trainig: 2.0294, Accuracy: 0.5000
# Batch no: 008, Loss on trainig: 2.2049, Accuracy: 0.4062
# Batch no: 009, Loss on trainig: 2.1557, Accuracy: 0.3438
# Batch no: 010, Loss on trainig: 2.4780, Accuracy: 0.3438
# Batch no: 011, Loss on trainig: 2.5096, Accuracy: 0.2812
# Batch no: 012, Loss on trainig: 2.2035, Accuracy: 0.4688
# Batch no: 013, Loss on trainig: 2.1196, Accuracy: 0.4062
# Batch no: 014, Loss on trainig: 1.8180, Accuracy: 0.4375
# Batch no: 015, Loss on trainig: 2.0405, Accuracy: 0.4688
# Batch no: 016, Loss on trainig: 2.7238, Accuracy: 0.2344
# Batch no: 017, Loss on trainig: 2.4109, Accuracy: 0.3594
# Batch no: 018, Loss on trainig: 2.1929, Accuracy: 0.3906
# Batch no: 019, Loss on trainig: 2.5842, Accuracy: 0.2812
# Batch no: 020, Loss on trainig: 2.5961, Accuracy: 0.4062
# Batch no: 021, Loss on trainig: 2.1443, Accuracy: 0.3594
# Batch no: 022, Loss on trainig: 2.4350, Accuracy: 0.3906
# Batch no: 023, Loss on trainig: 2.6856, Accuracy: 0.2969
# Batch no: 024, Loss on trainig: 2.1257, Accuracy: 0.4062
# Batch no: 025, Loss on trainig: 2.2563, Accuracy: 0.4219
# Batch no: 026, Loss on trainig: 2.2549, Accuracy: 0.4062
# Batch no: 027, Loss on trainig: 2.1772, Accuracy: 0.3906
# Batch no: 028, Loss on trainig: 2.2941, Accuracy: 0.3750
# Batch no: 029, Loss on trainig: 2.2291, Accuracy: 0.3906
# Batch no: 030, Loss on trainig: 2.0554, Accuracy: 0.4062
# Batch no: 031, Loss on trainig: 2.4717, Accuracy: 0.3438
# Batch no: 032, Loss on trainig: 1.6718, Accuracy: 0.5312
# Batch no: 033, Loss on trainig: 1.9251, Accuracy: 0.4688
# Batch no: 034, Loss on trainig: 1.9292, Accuracy: 0.4844
# Batch no: 035, Loss on trainig: 2.1321, Accuracy: 0.3906
# Batch no: 036, Loss on trainig: 2.1113, Accuracy: 0.4219
# Batch no: 037, Loss on trainig: 2.2529, Accuracy: 0.4219
# Batch no: 038, Loss on trainig: 2.4503, Accuracy: 0.3281
# Batch no: 039, Loss on trainig: 2.1160, Accuracy: 0.3750
# Batch no: 040, Loss on trainig: 2.4041, Accuracy: 0.3281
# Batch no: 041, Loss on trainig: 1.8689, Accuracy: 0.4844
# Batch no: 042, Loss on trainig: 2.6628, Accuracy: 0.2656
# Batch no: 043, Loss on trainig: 2.6081, Accuracy: 0.3125
# Batch no: 044, Loss on trainig: 2.3302, Accuracy: 0.4062
# Batch no: 045, Loss on trainig: 1.9578, Accuracy: 0.5156
# Batch no: 046, Loss on trainig: 2.0192, Accuracy: 0.4844
# Batch no: 047, Loss on trainig: 2.2147, Accuracy: 0.3906
# Batch no: 048, Loss on trainig: 2.2224, Accuracy: 0.4062
# Batch no: 049, Loss on trainig: 2.0665, Accuracy: 0.3906
# Batch no: 050, Loss on trainig: 2.2612, Accuracy: 0.3750
# Batch no: 051, Loss on trainig: 2.2006, Accuracy: 0.3594
# Batch no: 052, Loss on trainig: 2.0908, Accuracy: 0.3750
# Batch no: 053, Loss on trainig: 2.1642, Accuracy: 0.3594
# Batch no: 054, Loss on trainig: 1.7051, Accuracy: 0.5156
# Batch no: 055, Loss on trainig: 1.9562, Accuracy: 0.4688
# Batch no: 056, Loss on trainig: 2.0604, Accuracy: 0.4062
# Batch no: 057, Loss on trainig: 1.7109, Accuracy: 0.4688
# Batch no: 058, Loss on trainig: 2.4815, Accuracy: 0.4219
# Batch no: 059, Loss on trainig: 2.4248, Accuracy: 0.4062
# Batch no: 060, Loss on trainig: 2.2251, Accuracy: 0.4688
# Batch no: 061, Loss on trainig: 2.8492, Accuracy: 0.2812
# Batch no: 062, Loss on trainig: 1.9120, Accuracy: 0.5000
# Batch no: 063, Loss on trainig: 2.0426, Accuracy: 0.4531
# Batch no: 064, Loss on trainig: 2.2970, Accuracy: 0.3438
# Batch no: 065, Loss on trainig: 2.6730, Accuracy: 0.3125
# Batch no: 066, Loss on trainig: 2.2921, Accuracy: 0.3438
# Batch no: 067, Loss on trainig: 2.2726, Accuracy: 0.4062
# Batch no: 068, Loss on trainig: 2.2002, Accuracy: 0.3594
# Batch no: 069, Loss on trainig: 1.7981, Accuracy: 0.5312
# Batch no: 070, Loss on trainig: 2.1085, Accuracy: 0.4062
# Batch no: 071, Loss on trainig: 2.2505, Accuracy: 0.4688
# Batch no: 072, Loss on trainig: 2.1903, Accuracy: 0.4219
# Batch no: 073, Loss on trainig: 2.0181, Accuracy: 0.3125
# Batch no: 074, Loss on trainig: 2.2927, Accuracy: 0.4375
# Batch no: 075, Loss on trainig: 2.4437, Accuracy: 0.3750
# Batch no: 076, Loss on trainig: 1.5517, Accuracy: 0.5625
# Batch no: 077, Loss on trainig: 1.6814, Accuracy: 0.5000
# Batch no: 078, Loss on trainig: 2.2608, Accuracy: 0.3906
# Batch no: 079, Loss on trainig: 1.8904, Accuracy: 0.4062
# Batch no: 080, Loss on trainig: 1.9275, Accuracy: 0.4688
# Batch no: 081, Loss on trainig: 2.2350, Accuracy: 0.4062
# Batch no: 082, Loss on trainig: 2.2344, Accuracy: 0.3750
# Batch no: 083, Loss on trainig: 2.3301, Accuracy: 0.4062
# Batch no: 084, Loss on trainig: 2.5848, Accuracy: 0.3438
# Batch no: 085, Loss on trainig: 2.4992, Accuracy: 0.3906
# Batch no: 086, Loss on trainig: 2.3799, Accuracy: 0.4062
# Batch no: 087, Loss on trainig: 2.3565, Accuracy: 0.4219
# Batch no: 088, Loss on trainig: 2.1539, Accuracy: 0.3125
# Batch no: 089, Loss on trainig: 1.8243, Accuracy: 0.5000
# Batch no: 090, Loss on trainig: 2.0052, Accuracy: 0.3750
# Batch no: 091, Loss on trainig: 2.3846, Accuracy: 0.3438
# Batch no: 092, Loss on trainig: 2.4533, Accuracy: 0.3281
# Batch no: 093, Loss on trainig: 2.3149, Accuracy: 0.3438
# Batch no: 094, Loss on trainig: 2.1725, Accuracy: 0.4062
# Batch no: 095, Loss on trainig: 2.3204, Accuracy: 0.3906
# Batch no: 096, Loss on trainig: 2.2096, Accuracy: 0.3594
# Batch no: 097, Loss on trainig: 2.4180, Accuracy: 0.3125
# Batch no: 098, Loss on trainig: 1.8677, Accuracy: 0.4531
# Batch no: 099, Loss on trainig: 2.1843, Accuracy: 0.4062
# Batch no: 100, Loss on trainig: 2.0613, Accuracy: 0.4375
# Batch no: 101, Loss on trainig: 2.2849, Accuracy: 0.3906
# Batch no: 102, Loss on trainig: 1.9960, Accuracy: 0.3750
# Epoch: 4/10
# Batch no: 000, Loss on trainig: 2.2732, Accuracy: 0.5000
# Batch no: 001, Loss on trainig: 1.7904, Accuracy: 0.4688
# Batch no: 002, Loss on trainig: 1.7835, Accuracy: 0.4531
# Batch no: 003, Loss on trainig: 2.1870, Accuracy: 0.3906
# Batch no: 004, Loss on trainig: 1.8896, Accuracy: 0.4688
# Batch no: 005, Loss on trainig: 1.9093, Accuracy: 0.4531
# Batch no: 006, Loss on trainig: 2.0054, Accuracy: 0.4062
# Batch no: 007, Loss on trainig: 2.3697, Accuracy: 0.3438
# Batch no: 008, Loss on trainig: 2.1490, Accuracy: 0.4375
# Batch no: 009, Loss on trainig: 1.9065, Accuracy: 0.4375
# Batch no: 010, Loss on trainig: 1.7626, Accuracy: 0.4844
# Batch no: 011, Loss on trainig: 2.1880, Accuracy: 0.4062
# Batch no: 012, Loss on trainig: 1.8757, Accuracy: 0.4844
# Batch no: 013, Loss on trainig: 1.8289, Accuracy: 0.4531
# Batch no: 014, Loss on trainig: 2.5029, Accuracy: 0.3906
# Batch no: 015, Loss on trainig: 2.1441, Accuracy: 0.4062
# Batch no: 016, Loss on trainig: 1.9506, Accuracy: 0.4844
# Batch no: 017, Loss on trainig: 2.1989, Accuracy: 0.4688
# Batch no: 018, Loss on trainig: 1.8647, Accuracy: 0.5312
# Batch no: 019, Loss on trainig: 1.8629, Accuracy: 0.4375
# Batch no: 020, Loss on trainig: 1.8195, Accuracy: 0.4062
# Batch no: 021, Loss on trainig: 2.5346, Accuracy: 0.3750
# Batch no: 022, Loss on trainig: 2.1094, Accuracy: 0.4375
# Batch no: 023, Loss on trainig: 1.8959, Accuracy: 0.4688
# Batch no: 024, Loss on trainig: 2.0985, Accuracy: 0.4688
# Batch no: 025, Loss on trainig: 2.4969, Accuracy: 0.2969
# Batch no: 026, Loss on trainig: 1.9290, Accuracy: 0.4844
# Batch no: 027, Loss on trainig: 2.3388, Accuracy: 0.3594
# Batch no: 028, Loss on trainig: 1.9154, Accuracy: 0.5312
# Batch no: 029, Loss on trainig: 1.9215, Accuracy: 0.5156
# Batch no: 030, Loss on trainig: 2.4480, Accuracy: 0.3281
# Batch no: 031, Loss on trainig: 1.8856, Accuracy: 0.4062
# Batch no: 032, Loss on trainig: 1.7563, Accuracy: 0.4844
# Batch no: 033, Loss on trainig: 1.9698, Accuracy: 0.4531
# Batch no: 034, Loss on trainig: 1.8704, Accuracy: 0.4531
# Batch no: 035, Loss on trainig: 2.2665, Accuracy: 0.4062
# Batch no: 036, Loss on trainig: 1.9705, Accuracy: 0.4531
# Batch no: 037, Loss on trainig: 2.1649, Accuracy: 0.4531
# Batch no: 038, Loss on trainig: 2.0192, Accuracy: 0.4219
# Batch no: 039, Loss on trainig: 2.2275, Accuracy: 0.3906
# Batch no: 040, Loss on trainig: 2.0245, Accuracy: 0.4219
# Batch no: 041, Loss on trainig: 1.9698, Accuracy: 0.4844
# Batch no: 042, Loss on trainig: 2.1887, Accuracy: 0.4375
# Batch no: 043, Loss on trainig: 2.3434, Accuracy: 0.3594
# Batch no: 044, Loss on trainig: 2.1924, Accuracy: 0.3750
# Batch no: 045, Loss on trainig: 2.1437, Accuracy: 0.4062
# Batch no: 046, Loss on trainig: 1.5728, Accuracy: 0.5938
# Batch no: 047, Loss on trainig: 1.8547, Accuracy: 0.5156
# Batch no: 048, Loss on trainig: 2.0664, Accuracy: 0.4688
# Batch no: 049, Loss on trainig: 1.9200, Accuracy: 0.4219
# Batch no: 050, Loss on trainig: 2.3897, Accuracy: 0.3594
# Batch no: 051, Loss on trainig: 2.3830, Accuracy: 0.3594
# Batch no: 052, Loss on trainig: 2.1641, Accuracy: 0.3438
# Batch no: 053, Loss on trainig: 1.7609, Accuracy: 0.5312
# Batch no: 054, Loss on trainig: 1.9128, Accuracy: 0.4844
# Batch no: 055, Loss on trainig: 2.2100, Accuracy: 0.4375
# Batch no: 056, Loss on trainig: 2.2421, Accuracy: 0.4375
# Batch no: 057, Loss on trainig: 1.6304, Accuracy: 0.5156
# Batch no: 058, Loss on trainig: 1.9071, Accuracy: 0.4688
# Batch no: 059, Loss on trainig: 2.0902, Accuracy: 0.4531
# Batch no: 060, Loss on trainig: 2.0531, Accuracy: 0.4375
# Batch no: 061, Loss on trainig: 2.0102, Accuracy: 0.4531
# Batch no: 062, Loss on trainig: 2.0810, Accuracy: 0.4375
# Batch no: 063, Loss on trainig: 1.9793, Accuracy: 0.4375
# Batch no: 064, Loss on trainig: 2.0832, Accuracy: 0.4375
# Batch no: 065, Loss on trainig: 2.0791, Accuracy: 0.4531
# Batch no: 066, Loss on trainig: 2.3676, Accuracy: 0.3594
# Batch no: 067, Loss on trainig: 2.0249, Accuracy: 0.4219
# Batch no: 068, Loss on trainig: 2.3806, Accuracy: 0.3750
# Batch no: 069, Loss on trainig: 2.0073, Accuracy: 0.4062
# Batch no: 070, Loss on trainig: 1.7530, Accuracy: 0.5469
# Batch no: 071, Loss on trainig: 1.5210, Accuracy: 0.5312
# Batch no: 072, Loss on trainig: 1.9307, Accuracy: 0.5156
# Batch no: 073, Loss on trainig: 1.6808, Accuracy: 0.5625
# Batch no: 074, Loss on trainig: 2.0519, Accuracy: 0.3906
# Batch no: 075, Loss on trainig: 2.0769, Accuracy: 0.3438
# Batch no: 076, Loss on trainig: 2.1744, Accuracy: 0.4844
# Batch no: 077, Loss on trainig: 2.3684, Accuracy: 0.4062
# Batch no: 078, Loss on trainig: 2.0883, Accuracy: 0.4375
# Batch no: 079, Loss on trainig: 2.2676, Accuracy: 0.3906
# Batch no: 080, Loss on trainig: 1.9582, Accuracy: 0.3906
# Batch no: 081, Loss on trainig: 1.7589, Accuracy: 0.5156
# Batch no: 082, Loss on trainig: 1.9349, Accuracy: 0.5312
# Batch no: 083, Loss on trainig: 2.1385, Accuracy: 0.4219
# Batch no: 084, Loss on trainig: 2.5622, Accuracy: 0.3281
# Batch no: 085, Loss on trainig: 1.7413, Accuracy: 0.5625
# Batch no: 086, Loss on trainig: 1.9685, Accuracy: 0.4219
# Batch no: 087, Loss on trainig: 2.1223, Accuracy: 0.3438
# Batch no: 088, Loss on trainig: 1.6424, Accuracy: 0.5469
# Batch no: 089, Loss on trainig: 2.3666, Accuracy: 0.3906
# Batch no: 090, Loss on trainig: 2.2263, Accuracy: 0.3906
# Batch no: 091, Loss on trainig: 1.9900, Accuracy: 0.3906
# Batch no: 092, Loss on trainig: 1.8160, Accuracy: 0.4844
# Batch no: 093, Loss on trainig: 1.5553, Accuracy: 0.5781
# Batch no: 094, Loss on trainig: 1.9952, Accuracy: 0.4844
# Batch no: 095, Loss on trainig: 2.3445, Accuracy: 0.3281
# Batch no: 096, Loss on trainig: 2.2771, Accuracy: 0.3594
# Batch no: 097, Loss on trainig: 1.3333, Accuracy: 0.6406
# Batch no: 098, Loss on trainig: 1.4534, Accuracy: 0.5625
# Batch no: 099, Loss on trainig: 2.1012, Accuracy: 0.4062
# Batch no: 100, Loss on trainig: 2.0506, Accuracy: 0.4531
# Batch no: 101, Loss on trainig: 1.9166, Accuracy: 0.4688
# Batch no: 102, Loss on trainig: 2.1861, Accuracy: 0.4583
# Epoch: 5/10
# Batch no: 000, Loss on trainig: 1.9493, Accuracy: 0.3906
# Batch no: 001, Loss on trainig: 1.8964, Accuracy: 0.4375
# Batch no: 002, Loss on trainig: 2.0658, Accuracy: 0.4375
# Batch no: 003, Loss on trainig: 1.7760, Accuracy: 0.5156
# Batch no: 004, Loss on trainig: 1.7969, Accuracy: 0.4531
# Batch no: 005, Loss on trainig: 2.1150, Accuracy: 0.4375
# Batch no: 006, Loss on trainig: 1.9034, Accuracy: 0.4062
# Batch no: 007, Loss on trainig: 2.1599, Accuracy: 0.4844
# Batch no: 008, Loss on trainig: 2.1370, Accuracy: 0.3750
# Batch no: 009, Loss on trainig: 2.2028, Accuracy: 0.3438
# Batch no: 010, Loss on trainig: 2.1476, Accuracy: 0.3906
# Batch no: 011, Loss on trainig: 1.7984, Accuracy: 0.5156
# Batch no: 012, Loss on trainig: 2.1538, Accuracy: 0.4844
# Batch no: 013, Loss on trainig: 1.5465, Accuracy: 0.5625
# Batch no: 014, Loss on trainig: 1.8308, Accuracy: 0.5156
# Batch no: 015, Loss on trainig: 1.9032, Accuracy: 0.5000
# Batch no: 016, Loss on trainig: 1.6211, Accuracy: 0.5156
# Batch no: 017, Loss on trainig: 1.7602, Accuracy: 0.5000
# Batch no: 018, Loss on trainig: 2.0368, Accuracy: 0.4688
# Batch no: 019, Loss on trainig: 2.1638, Accuracy: 0.5000
# Batch no: 020, Loss on trainig: 1.4891, Accuracy: 0.6250
# Batch no: 021, Loss on trainig: 2.0013, Accuracy: 0.4688
# Batch no: 022, Loss on trainig: 1.9694, Accuracy: 0.4062
# Batch no: 023, Loss on trainig: 1.8198, Accuracy: 0.4688
# Batch no: 024, Loss on trainig: 1.6833, Accuracy: 0.5625
# Batch no: 025, Loss on trainig: 1.8971, Accuracy: 0.5781
# Batch no: 026, Loss on trainig: 1.8599, Accuracy: 0.4844
# Batch no: 027, Loss on trainig: 2.0636, Accuracy: 0.4219
# Batch no: 028, Loss on trainig: 1.9367, Accuracy: 0.5000
# Batch no: 029, Loss on trainig: 1.9561, Accuracy: 0.4531
# Batch no: 030, Loss on trainig: 1.8886, Accuracy: 0.4844
# Batch no: 031, Loss on trainig: 1.6829, Accuracy: 0.5000
# Batch no: 032, Loss on trainig: 2.0929, Accuracy: 0.4219
# Batch no: 033, Loss on trainig: 1.7808, Accuracy: 0.6094
# Batch no: 034, Loss on trainig: 1.8159, Accuracy: 0.4219
# Batch no: 035, Loss on trainig: 1.9475, Accuracy: 0.4844
# Batch no: 036, Loss on trainig: 1.8813, Accuracy: 0.5312
# Batch no: 037, Loss on trainig: 1.8031, Accuracy: 0.5156
# Batch no: 038, Loss on trainig: 2.2322, Accuracy: 0.4531
# Batch no: 039, Loss on trainig: 1.8872, Accuracy: 0.5312
# Batch no: 040, Loss on trainig: 1.5904, Accuracy: 0.5469
# Batch no: 041, Loss on trainig: 1.5493, Accuracy: 0.5625
# Batch no: 042, Loss on trainig: 1.9487, Accuracy: 0.5156
# Batch no: 043, Loss on trainig: 1.7345, Accuracy: 0.5312
# Batch no: 044, Loss on trainig: 1.8526, Accuracy: 0.4844
# Batch no: 045, Loss on trainig: 1.8683, Accuracy: 0.5000
# Batch no: 046, Loss on trainig: 2.0924, Accuracy: 0.4688
# Batch no: 047, Loss on trainig: 1.9678, Accuracy: 0.4531
# Batch no: 048, Loss on trainig: 2.0500, Accuracy: 0.3906
# Batch no: 049, Loss on trainig: 1.8075, Accuracy: 0.4688
# Batch no: 050, Loss on trainig: 1.7235, Accuracy: 0.5000
# Batch no: 051, Loss on trainig: 1.8478, Accuracy: 0.5156
# Batch no: 052, Loss on trainig: 1.9277, Accuracy: 0.5000
# Batch no: 053, Loss on trainig: 1.6334, Accuracy: 0.4844
# Batch no: 054, Loss on trainig: 1.9172, Accuracy: 0.4531
# Batch no: 055, Loss on trainig: 1.7412, Accuracy: 0.5000
# Batch no: 056, Loss on trainig: 1.6246, Accuracy: 0.5312
# Batch no: 057, Loss on trainig: 1.9944, Accuracy: 0.4219
# Batch no: 058, Loss on trainig: 1.8043, Accuracy: 0.4531
# Batch no: 059, Loss on trainig: 1.8414, Accuracy: 0.5000
# Batch no: 060, Loss on trainig: 1.8543, Accuracy: 0.3906
# Batch no: 061, Loss on trainig: 1.7226, Accuracy: 0.4844
# Batch no: 062, Loss on trainig: 1.8837, Accuracy: 0.5000
# Batch no: 063, Loss on trainig: 2.1463, Accuracy: 0.4531
# Batch no: 064, Loss on trainig: 2.1651, Accuracy: 0.4062
# Batch no: 065, Loss on trainig: 1.9941, Accuracy: 0.4531
# Batch no: 066, Loss on trainig: 2.4372, Accuracy: 0.4219
# Batch no: 067, Loss on trainig: 2.0512, Accuracy: 0.5000
# Batch no: 068, Loss on trainig: 2.1568, Accuracy: 0.4531
# Batch no: 069, Loss on trainig: 1.9755, Accuracy: 0.4375
# Batch no: 070, Loss on trainig: 2.0036, Accuracy: 0.3906
# Batch no: 071, Loss on trainig: 1.8808, Accuracy: 0.5312
# Batch no: 072, Loss on trainig: 2.0122, Accuracy: 0.4062
# Batch no: 073, Loss on trainig: 1.7115, Accuracy: 0.5469
# Batch no: 074, Loss on trainig: 2.0192, Accuracy: 0.5312
# Batch no: 075, Loss on trainig: 2.1500, Accuracy: 0.4688
# Batch no: 076, Loss on trainig: 1.8193, Accuracy: 0.5000
# Batch no: 077, Loss on trainig: 1.7919, Accuracy: 0.4688
# Batch no: 078, Loss on trainig: 1.8688, Accuracy: 0.5000
# Batch no: 079, Loss on trainig: 2.0690, Accuracy: 0.4219
# Batch no: 080, Loss on trainig: 1.8811, Accuracy: 0.4844
# Batch no: 081, Loss on trainig: 2.1229, Accuracy: 0.4531
# Batch no: 082, Loss on trainig: 1.9878, Accuracy: 0.4688
# Batch no: 083, Loss on trainig: 1.6352, Accuracy: 0.5625
# Batch no: 084, Loss on trainig: 2.2255, Accuracy: 0.4375
# Batch no: 085, Loss on trainig: 2.0992, Accuracy: 0.5469
# Batch no: 086, Loss on trainig: 1.9250, Accuracy: 0.5000
# Batch no: 087, Loss on trainig: 1.5918, Accuracy: 0.5625
# Batch no: 088, Loss on trainig: 1.9101, Accuracy: 0.4688
# Batch no: 089, Loss on trainig: 1.7316, Accuracy: 0.5781
# Batch no: 090, Loss on trainig: 1.9831, Accuracy: 0.4375
# Batch no: 091, Loss on trainig: 1.9172, Accuracy: 0.4531
# Batch no: 092, Loss on trainig: 1.7999, Accuracy: 0.5000
# Batch no: 093, Loss on trainig: 1.7012, Accuracy: 0.5000
# Batch no: 094, Loss on trainig: 1.9708, Accuracy: 0.4375
# Batch no: 095, Loss on trainig: 1.9439, Accuracy: 0.5156
# Batch no: 096, Loss on trainig: 2.1758, Accuracy: 0.4219
# Batch no: 097, Loss on trainig: 1.7613, Accuracy: 0.5312
# Batch no: 098, Loss on trainig: 1.8622, Accuracy: 0.4844
# Batch no: 099, Loss on trainig: 2.0548, Accuracy: 0.4688
# Batch no: 100, Loss on trainig: 1.5630, Accuracy: 0.5312
# Batch no: 101, Loss on trainig: 2.1639, Accuracy: 0.3750
# Batch no: 102, Loss on trainig: 1.8530, Accuracy: 0.4583
# Epoch: 6/10
# Batch no: 000, Loss on trainig: 1.9011, Accuracy: 0.5156
# Batch no: 001, Loss on trainig: 1.9088, Accuracy: 0.4844
# Batch no: 002, Loss on trainig: 1.6663, Accuracy: 0.5156
# Batch no: 003, Loss on trainig: 1.8361, Accuracy: 0.5469
# Batch no: 004, Loss on trainig: 1.9177, Accuracy: 0.4219
# Batch no: 005, Loss on trainig: 2.0424, Accuracy: 0.3906
# Batch no: 006, Loss on trainig: 1.7509, Accuracy: 0.5312
# Batch no: 007, Loss on trainig: 1.7535, Accuracy: 0.5156
# Batch no: 008, Loss on trainig: 1.6716, Accuracy: 0.5469
# Batch no: 009, Loss on trainig: 1.8006, Accuracy: 0.4219
# Batch no: 010, Loss on trainig: 1.6916, Accuracy: 0.5156
# Batch no: 011, Loss on trainig: 1.5038, Accuracy: 0.6094
# Batch no: 012, Loss on trainig: 1.7511, Accuracy: 0.5156
# Batch no: 013, Loss on trainig: 2.2055, Accuracy: 0.3906
# Batch no: 014, Loss on trainig: 1.7828, Accuracy: 0.5312
# Batch no: 015, Loss on trainig: 2.2108, Accuracy: 0.4844
# Batch no: 016, Loss on trainig: 2.0740, Accuracy: 0.4688
# Batch no: 017, Loss on trainig: 1.7783, Accuracy: 0.5000
# Batch no: 018, Loss on trainig: 1.4699, Accuracy: 0.5312
# Batch no: 019, Loss on trainig: 1.4758, Accuracy: 0.6250
# Batch no: 020, Loss on trainig: 2.3966, Accuracy: 0.4219
# Batch no: 021, Loss on trainig: 1.6974, Accuracy: 0.5312
# Batch no: 022, Loss on trainig: 1.5566, Accuracy: 0.5312
# Batch no: 023, Loss on trainig: 2.0296, Accuracy: 0.4531
# Batch no: 024, Loss on trainig: 1.8667, Accuracy: 0.3906
# Batch no: 025, Loss on trainig: 2.0269, Accuracy: 0.4688
# Batch no: 026, Loss on trainig: 2.0064, Accuracy: 0.4531
# Batch no: 027, Loss on trainig: 1.9213, Accuracy: 0.4844
# Batch no: 028, Loss on trainig: 1.7541, Accuracy: 0.4844
# Batch no: 029, Loss on trainig: 1.9846, Accuracy: 0.4844
# Batch no: 030, Loss on trainig: 1.5016, Accuracy: 0.5625
# Batch no: 031, Loss on trainig: 2.1092, Accuracy: 0.5000
# Batch no: 032, Loss on trainig: 1.8332, Accuracy: 0.4844
# Batch no: 033, Loss on trainig: 1.4017, Accuracy: 0.6250
# Batch no: 034, Loss on trainig: 1.4970, Accuracy: 0.5625
# Batch no: 035, Loss on trainig: 2.2293, Accuracy: 0.4688
# Batch no: 036, Loss on trainig: 2.0243, Accuracy: 0.4688
# Batch no: 037, Loss on trainig: 1.4752, Accuracy: 0.5938
# Batch no: 038, Loss on trainig: 1.8203, Accuracy: 0.4688
# Batch no: 039, Loss on trainig: 2.1422, Accuracy: 0.3906
# Batch no: 040, Loss on trainig: 2.0362, Accuracy: 0.5156
# Batch no: 041, Loss on trainig: 1.6976, Accuracy: 0.5469
# Batch no: 042, Loss on trainig: 1.8555, Accuracy: 0.5000
# Batch no: 043, Loss on trainig: 1.6912, Accuracy: 0.5156
# Batch no: 044, Loss on trainig: 1.9719, Accuracy: 0.4375
# Batch no: 045, Loss on trainig: 1.7705, Accuracy: 0.5000
# Batch no: 046, Loss on trainig: 1.7178, Accuracy: 0.5156
# Batch no: 047, Loss on trainig: 1.9593, Accuracy: 0.4844
# Batch no: 048, Loss on trainig: 1.7761, Accuracy: 0.4688
# Batch no: 049, Loss on trainig: 1.6220, Accuracy: 0.5938
# Batch no: 050, Loss on trainig: 1.9559, Accuracy: 0.4062
# Batch no: 051, Loss on trainig: 1.8043, Accuracy: 0.5156
# Batch no: 052, Loss on trainig: 1.7887, Accuracy: 0.4844
# Batch no: 053, Loss on trainig: 2.1486, Accuracy: 0.3906
# Batch no: 054, Loss on trainig: 2.0070, Accuracy: 0.3594
# Batch no: 055, Loss on trainig: 2.2181, Accuracy: 0.5000
# Batch no: 056, Loss on trainig: 1.7812, Accuracy: 0.5312
# Batch no: 057, Loss on trainig: 1.8495, Accuracy: 0.4375
# Batch no: 058, Loss on trainig: 1.6355, Accuracy: 0.5781
# Batch no: 059, Loss on trainig: 1.8929, Accuracy: 0.4688
# Batch no: 060, Loss on trainig: 1.8308, Accuracy: 0.5469
# Batch no: 061, Loss on trainig: 1.4470, Accuracy: 0.5781
# Batch no: 062, Loss on trainig: 1.8968, Accuracy: 0.4375
# Batch no: 063, Loss on trainig: 1.7835, Accuracy: 0.4688
# Batch no: 064, Loss on trainig: 2.0127, Accuracy: 0.4375
# Batch no: 065, Loss on trainig: 1.5973, Accuracy: 0.5469
# Batch no: 066, Loss on trainig: 1.9693, Accuracy: 0.5781
# Batch no: 067, Loss on trainig: 1.9929, Accuracy: 0.3906
# Batch no: 068, Loss on trainig: 2.0499, Accuracy: 0.4688
# Batch no: 069, Loss on trainig: 1.7616, Accuracy: 0.5312
# Batch no: 070, Loss on trainig: 1.9660, Accuracy: 0.4375
# Batch no: 071, Loss on trainig: 1.5628, Accuracy: 0.5312
# Batch no: 072, Loss on trainig: 1.7737, Accuracy: 0.5469
# Batch no: 073, Loss on trainig: 1.7758, Accuracy: 0.5156
# Batch no: 074, Loss on trainig: 1.7556, Accuracy: 0.5156
# Batch no: 075, Loss on trainig: 1.8113, Accuracy: 0.5000
# Batch no: 076, Loss on trainig: 1.5000, Accuracy: 0.5312
# Batch no: 077, Loss on trainig: 1.7972, Accuracy: 0.5156
# Batch no: 078, Loss on trainig: 2.2651, Accuracy: 0.4219
# Batch no: 079, Loss on trainig: 1.5515, Accuracy: 0.5625
# Batch no: 080, Loss on trainig: 1.9054, Accuracy: 0.4688
# Batch no: 081, Loss on trainig: 1.6746, Accuracy: 0.5781
# Batch no: 082, Loss on trainig: 1.7774, Accuracy: 0.4688
# Batch no: 083, Loss on trainig: 1.7356, Accuracy: 0.5781
# Batch no: 084, Loss on trainig: 1.6677, Accuracy: 0.5938
# Batch no: 085, Loss on trainig: 1.5786, Accuracy: 0.6250
# Batch no: 086, Loss on trainig: 1.6179, Accuracy: 0.5312
# Batch no: 087, Loss on trainig: 1.4928, Accuracy: 0.5469
# Batch no: 088, Loss on trainig: 1.7235, Accuracy: 0.4844
# Batch no: 089, Loss on trainig: 1.8678, Accuracy: 0.4688
# Batch no: 090, Loss on trainig: 1.5721, Accuracy: 0.5781
# Batch no: 091, Loss on trainig: 1.9986, Accuracy: 0.4688
# Batch no: 092, Loss on trainig: 1.6648, Accuracy: 0.5312
# Batch no: 093, Loss on trainig: 1.8058, Accuracy: 0.4844
# Batch no: 094, Loss on trainig: 1.7476, Accuracy: 0.5156
# Batch no: 095, Loss on trainig: 1.4871, Accuracy: 0.5312
# Batch no: 096, Loss on trainig: 1.9707, Accuracy: 0.4844
# Batch no: 097, Loss on trainig: 1.5433, Accuracy: 0.6562
# Batch no: 098, Loss on trainig: 1.7895, Accuracy: 0.5000
# Batch no: 099, Loss on trainig: 1.5572, Accuracy: 0.5312
# Batch no: 100, Loss on trainig: 1.8608, Accuracy: 0.5469
# Batch no: 101, Loss on trainig: 1.4909, Accuracy: 0.5781
# Batch no: 102, Loss on trainig: 1.2968, Accuracy: 0.7500
# Epoch: 7/10
# Batch no: 000, Loss on trainig: 1.4934, Accuracy: 0.5312
# Batch no: 001, Loss on trainig: 1.5020, Accuracy: 0.5938
# Batch no: 002, Loss on trainig: 1.5011, Accuracy: 0.5781
# Batch no: 003, Loss on trainig: 1.8355, Accuracy: 0.5156
# Batch no: 004, Loss on trainig: 1.4234, Accuracy: 0.5938
# Batch no: 005, Loss on trainig: 1.5382, Accuracy: 0.5469
# Batch no: 006, Loss on trainig: 1.5977, Accuracy: 0.5625
# Batch no: 007, Loss on trainig: 1.3411, Accuracy: 0.6094
# Batch no: 008, Loss on trainig: 2.4131, Accuracy: 0.3281
# Batch no: 009, Loss on trainig: 1.5812, Accuracy: 0.5469
# Batch no: 010, Loss on trainig: 1.3653, Accuracy: 0.5625
# Batch no: 011, Loss on trainig: 1.6237, Accuracy: 0.5312
# Batch no: 012, Loss on trainig: 1.7738, Accuracy: 0.5312
# Batch no: 013, Loss on trainig: 1.8447, Accuracy: 0.5000
# Batch no: 014, Loss on trainig: 1.4658, Accuracy: 0.5938
# Batch no: 015, Loss on trainig: 1.7836, Accuracy: 0.5312
# Batch no: 016, Loss on trainig: 1.6232, Accuracy: 0.6094
# Batch no: 017, Loss on trainig: 2.0003, Accuracy: 0.4375
# Batch no: 018, Loss on trainig: 1.5902, Accuracy: 0.4844
# Batch no: 019, Loss on trainig: 2.2021, Accuracy: 0.5000
# Batch no: 020, Loss on trainig: 1.9149, Accuracy: 0.5469
# Batch no: 021, Loss on trainig: 1.5290, Accuracy: 0.5938
# Batch no: 022, Loss on trainig: 1.6917, Accuracy: 0.5938
# Batch no: 023, Loss on trainig: 1.6192, Accuracy: 0.6094
# Batch no: 024, Loss on trainig: 1.6398, Accuracy: 0.5625
# Batch no: 025, Loss on trainig: 1.4478, Accuracy: 0.5469
# Batch no: 026, Loss on trainig: 1.9079, Accuracy: 0.4219
# Batch no: 027, Loss on trainig: 1.5461, Accuracy: 0.6094
# Batch no: 028, Loss on trainig: 2.1437, Accuracy: 0.5156
# Batch no: 029, Loss on trainig: 1.4968, Accuracy: 0.5781
# Batch no: 030, Loss on trainig: 1.9050, Accuracy: 0.4531
# Batch no: 031, Loss on trainig: 1.9494, Accuracy: 0.5156
# Batch no: 032, Loss on trainig: 1.7738, Accuracy: 0.4688
# Batch no: 033, Loss on trainig: 1.5920, Accuracy: 0.5312
# Batch no: 034, Loss on trainig: 1.4705, Accuracy: 0.5625
# Batch no: 035, Loss on trainig: 1.9831, Accuracy: 0.5625
# Batch no: 036, Loss on trainig: 1.5314, Accuracy: 0.5625
# Batch no: 037, Loss on trainig: 1.7680, Accuracy: 0.5156
# Batch no: 038, Loss on trainig: 1.7536, Accuracy: 0.5000
# Batch no: 039, Loss on trainig: 2.0768, Accuracy: 0.4062
# Batch no: 040, Loss on trainig: 1.5325, Accuracy: 0.5000
# Batch no: 041, Loss on trainig: 1.4942, Accuracy: 0.5156
# Batch no: 042, Loss on trainig: 1.6913, Accuracy: 0.5156
# Batch no: 043, Loss on trainig: 1.7583, Accuracy: 0.5625
# Batch no: 044, Loss on trainig: 1.6082, Accuracy: 0.4531
# Batch no: 045, Loss on trainig: 1.4368, Accuracy: 0.5625
# Batch no: 046, Loss on trainig: 1.6794, Accuracy: 0.5312
# Batch no: 047, Loss on trainig: 1.5839, Accuracy: 0.5469
# Batch no: 048, Loss on trainig: 1.3354, Accuracy: 0.5625
# Batch no: 049, Loss on trainig: 1.7974, Accuracy: 0.5312
# Batch no: 050, Loss on trainig: 1.5049, Accuracy: 0.5469
# Batch no: 051, Loss on trainig: 1.3192, Accuracy: 0.6094
# Batch no: 052, Loss on trainig: 1.7630, Accuracy: 0.5000
# Batch no: 053, Loss on trainig: 1.9414, Accuracy: 0.4844
# Batch no: 054, Loss on trainig: 1.7026, Accuracy: 0.5312
# Batch no: 055, Loss on trainig: 1.5228, Accuracy: 0.5625
# Batch no: 056, Loss on trainig: 1.8734, Accuracy: 0.4688
# Batch no: 057, Loss on trainig: 2.1193, Accuracy: 0.4219
# Batch no: 058, Loss on trainig: 1.7623, Accuracy: 0.5156
# Batch no: 059, Loss on trainig: 2.0871, Accuracy: 0.5000
# Batch no: 060, Loss on trainig: 1.8546, Accuracy: 0.4688
# Batch no: 061, Loss on trainig: 1.9891, Accuracy: 0.5312
# Batch no: 062, Loss on trainig: 1.5910, Accuracy: 0.5625
# Batch no: 063, Loss on trainig: 1.6390, Accuracy: 0.5625
# Batch no: 064, Loss on trainig: 1.5565, Accuracy: 0.5938
# Batch no: 065, Loss on trainig: 1.2228, Accuracy: 0.6406
# Batch no: 066, Loss on trainig: 1.4342, Accuracy: 0.5781
# Batch no: 067, Loss on trainig: 1.6757, Accuracy: 0.5469
# Batch no: 068, Loss on trainig: 2.0238, Accuracy: 0.5000
# Batch no: 069, Loss on trainig: 1.4899, Accuracy: 0.5781
# Batch no: 070, Loss on trainig: 1.9033, Accuracy: 0.5469
# Batch no: 071, Loss on trainig: 1.4658, Accuracy: 0.5938
# Batch no: 072, Loss on trainig: 1.5484, Accuracy: 0.5625
# Batch no: 073, Loss on trainig: 1.8790, Accuracy: 0.3906
# Batch no: 074, Loss on trainig: 1.5680, Accuracy: 0.6250
# Batch no: 075, Loss on trainig: 1.9184, Accuracy: 0.5000
# Batch no: 076, Loss on trainig: 1.5742, Accuracy: 0.5000
# Batch no: 077, Loss on trainig: 1.4373, Accuracy: 0.6094
# Batch no: 078, Loss on trainig: 2.3230, Accuracy: 0.4531
# Batch no: 079, Loss on trainig: 1.6724, Accuracy: 0.5469
# Batch no: 080, Loss on trainig: 1.7330, Accuracy: 0.4688
# Batch no: 081, Loss on trainig: 1.7073, Accuracy: 0.5312
# Batch no: 082, Loss on trainig: 1.8554, Accuracy: 0.5312
# Batch no: 083, Loss on trainig: 1.5535, Accuracy: 0.4688
# Batch no: 084, Loss on trainig: 1.7459, Accuracy: 0.5781
# Batch no: 085, Loss on trainig: 1.7437, Accuracy: 0.5000
# Batch no: 086, Loss on trainig: 1.2217, Accuracy: 0.6875
# Batch no: 087, Loss on trainig: 1.9143, Accuracy: 0.4531
# Batch no: 088, Loss on trainig: 1.2114, Accuracy: 0.6250
# Batch no: 089, Loss on trainig: 1.7762, Accuracy: 0.5000
# Batch no: 090, Loss on trainig: 2.1429, Accuracy: 0.4219
# Batch no: 091, Loss on trainig: 1.3965, Accuracy: 0.6094
# Batch no: 092, Loss on trainig: 1.5639, Accuracy: 0.5000
# Batch no: 093, Loss on trainig: 1.5603, Accuracy: 0.5625
# Batch no: 094, Loss on trainig: 1.7760, Accuracy: 0.4531
# Batch no: 095, Loss on trainig: 1.8169, Accuracy: 0.5000
# Batch no: 096, Loss on trainig: 1.6390, Accuracy: 0.6094
# Batch no: 097, Loss on trainig: 1.6797, Accuracy: 0.5000
# Batch no: 098, Loss on trainig: 1.7290, Accuracy: 0.5469
# Batch no: 099, Loss on trainig: 1.5346, Accuracy: 0.6406
# Batch no: 100, Loss on trainig: 1.6693, Accuracy: 0.5156
# Batch no: 101, Loss on trainig: 1.8152, Accuracy: 0.4375
# Batch no: 102, Loss on trainig: 2.0489, Accuracy: 0.2500
# Epoch: 8/10
# Batch no: 000, Loss on trainig: 1.6872, Accuracy: 0.4688
# Batch no: 001, Loss on trainig: 1.4553, Accuracy: 0.5938
# Batch no: 002, Loss on trainig: 1.5098, Accuracy: 0.6094
# Batch no: 003, Loss on trainig: 1.5622, Accuracy: 0.5938
# Batch no: 004, Loss on trainig: 1.6102, Accuracy: 0.5469
# Batch no: 005, Loss on trainig: 1.2970, Accuracy: 0.5938
# Batch no: 006, Loss on trainig: 1.7825, Accuracy: 0.5000
# Batch no: 007, Loss on trainig: 1.6322, Accuracy: 0.6094
# Batch no: 008, Loss on trainig: 1.7327, Accuracy: 0.5625
# Batch no: 009, Loss on trainig: 1.8554, Accuracy: 0.4844
# Batch no: 010, Loss on trainig: 1.4728, Accuracy: 0.5469
# Batch no: 011, Loss on trainig: 1.7670, Accuracy: 0.5781
# Batch no: 012, Loss on trainig: 1.6565, Accuracy: 0.5781
# Batch no: 013, Loss on trainig: 1.5977, Accuracy: 0.5781
# Batch no: 014, Loss on trainig: 1.3366, Accuracy: 0.7031
# Batch no: 015, Loss on trainig: 1.9572, Accuracy: 0.3594
# Batch no: 016, Loss on trainig: 1.5275, Accuracy: 0.5156
# Batch no: 017, Loss on trainig: 1.3874, Accuracy: 0.5625
# Batch no: 018, Loss on trainig: 1.5413, Accuracy: 0.5156
# Batch no: 019, Loss on trainig: 2.1714, Accuracy: 0.4375
# Batch no: 020, Loss on trainig: 1.7573, Accuracy: 0.5312
# Batch no: 021, Loss on trainig: 1.6913, Accuracy: 0.5156
# Batch no: 022, Loss on trainig: 1.5565, Accuracy: 0.5469
# Batch no: 023, Loss on trainig: 1.5763, Accuracy: 0.5625
# Batch no: 024, Loss on trainig: 1.5304, Accuracy: 0.5625
# Batch no: 025, Loss on trainig: 1.8359, Accuracy: 0.4531
# Batch no: 026, Loss on trainig: 1.5828, Accuracy: 0.5781
# Batch no: 027, Loss on trainig: 1.7469, Accuracy: 0.5469
# Batch no: 028, Loss on trainig: 2.0364, Accuracy: 0.5000
# Batch no: 029, Loss on trainig: 1.5721, Accuracy: 0.5469
# Batch no: 030, Loss on trainig: 2.0268, Accuracy: 0.4375
# Batch no: 031, Loss on trainig: 1.3638, Accuracy: 0.6406
# Batch no: 032, Loss on trainig: 1.4924, Accuracy: 0.5469
# Batch no: 033, Loss on trainig: 1.4933, Accuracy: 0.5625
# Batch no: 034, Loss on trainig: 2.0643, Accuracy: 0.4688
# Batch no: 035, Loss on trainig: 1.7826, Accuracy: 0.5781
# Batch no: 036, Loss on trainig: 2.1878, Accuracy: 0.4219
# Batch no: 037, Loss on trainig: 1.4956, Accuracy: 0.5938
# Batch no: 038, Loss on trainig: 2.0494, Accuracy: 0.4219
# Batch no: 039, Loss on trainig: 1.5358, Accuracy: 0.5312
# Batch no: 040, Loss on trainig: 1.6622, Accuracy: 0.5000
# Batch no: 041, Loss on trainig: 1.7981, Accuracy: 0.5312
# Batch no: 042, Loss on trainig: 1.6538, Accuracy: 0.5469
# Batch no: 043, Loss on trainig: 1.7569, Accuracy: 0.4844
# Batch no: 044, Loss on trainig: 1.7056, Accuracy: 0.5000
# Batch no: 045, Loss on trainig: 1.7220, Accuracy: 0.4844
# Batch no: 046, Loss on trainig: 1.6172, Accuracy: 0.5312
# Batch no: 047, Loss on trainig: 1.5952, Accuracy: 0.5781
# Batch no: 048, Loss on trainig: 1.3872, Accuracy: 0.6875
# Batch no: 049, Loss on trainig: 1.7644, Accuracy: 0.5469
# Batch no: 050, Loss on trainig: 1.2358, Accuracy: 0.6406
# Batch no: 051, Loss on trainig: 1.9427, Accuracy: 0.4688
# Batch no: 052, Loss on trainig: 1.5236, Accuracy: 0.5625
# Batch no: 053, Loss on trainig: 2.0430, Accuracy: 0.4844
# Batch no: 054, Loss on trainig: 1.7675, Accuracy: 0.5469
# Batch no: 055, Loss on trainig: 1.7942, Accuracy: 0.5781
# Batch no: 056, Loss on trainig: 1.3516, Accuracy: 0.6094
# Batch no: 057, Loss on trainig: 2.1140, Accuracy: 0.4844
# Batch no: 058, Loss on trainig: 2.0773, Accuracy: 0.4062
# Batch no: 059, Loss on trainig: 1.4055, Accuracy: 0.5469
# Batch no: 060, Loss on trainig: 1.5006, Accuracy: 0.6094
# Batch no: 061, Loss on trainig: 1.6445, Accuracy: 0.5625
# Batch no: 062, Loss on trainig: 1.5088, Accuracy: 0.5781
# Batch no: 063, Loss on trainig: 1.6221, Accuracy: 0.5469
# Batch no: 064, Loss on trainig: 1.6764, Accuracy: 0.5469
# Batch no: 065, Loss on trainig: 1.8382, Accuracy: 0.5000
# Batch no: 066, Loss on trainig: 1.5220, Accuracy: 0.6250
# Batch no: 067, Loss on trainig: 1.5506, Accuracy: 0.5781
# Batch no: 068, Loss on trainig: 1.6573, Accuracy: 0.5156
# Batch no: 069, Loss on trainig: 1.7200, Accuracy: 0.5312
# Batch no: 070, Loss on trainig: 1.4855, Accuracy: 0.5625
# Batch no: 071, Loss on trainig: 2.0314, Accuracy: 0.4375
# Batch no: 072, Loss on trainig: 1.9589, Accuracy: 0.4531
# Batch no: 073, Loss on trainig: 1.9344, Accuracy: 0.4531
# Batch no: 074, Loss on trainig: 1.9070, Accuracy: 0.5000
# Batch no: 075, Loss on trainig: 2.0222, Accuracy: 0.5156
# Batch no: 076, Loss on trainig: 1.7499, Accuracy: 0.4375
# Batch no: 077, Loss on trainig: 1.8893, Accuracy: 0.4531
# Batch no: 078, Loss on trainig: 1.4162, Accuracy: 0.5781
# Batch no: 079, Loss on trainig: 1.4278, Accuracy: 0.5312
# Batch no: 080, Loss on trainig: 1.4444, Accuracy: 0.5781
# Batch no: 081, Loss on trainig: 1.5081, Accuracy: 0.5469
# Batch no: 082, Loss on trainig: 1.3114, Accuracy: 0.5938
# Batch no: 083, Loss on trainig: 1.7965, Accuracy: 0.6406
# Batch no: 084, Loss on trainig: 1.9926, Accuracy: 0.4688
# Batch no: 085, Loss on trainig: 1.7441, Accuracy: 0.5312
# Batch no: 086, Loss on trainig: 1.9522, Accuracy: 0.5000
# Batch no: 087, Loss on trainig: 1.8028, Accuracy: 0.4688
# Batch no: 088, Loss on trainig: 1.7828, Accuracy: 0.5156
# Batch no: 089, Loss on trainig: 1.7343, Accuracy: 0.5156
# Batch no: 090, Loss on trainig: 1.1787, Accuracy: 0.6875
# Batch no: 091, Loss on trainig: 2.0260, Accuracy: 0.4375
# Batch no: 092, Loss on trainig: 1.9746, Accuracy: 0.4688
# Batch no: 093, Loss on trainig: 1.4807, Accuracy: 0.6406
# Batch no: 094, Loss on trainig: 1.8055, Accuracy: 0.5156
# Batch no: 095, Loss on trainig: 1.9647, Accuracy: 0.3906
# Batch no: 096, Loss on trainig: 1.8313, Accuracy: 0.5781
# Batch no: 097, Loss on trainig: 1.8947, Accuracy: 0.5156
# Batch no: 098, Loss on trainig: 1.6093, Accuracy: 0.5781
# Batch no: 099, Loss on trainig: 1.8304, Accuracy: 0.5156
# Batch no: 100, Loss on trainig: 1.8491, Accuracy: 0.5625
# Batch no: 101, Loss on trainig: 1.3170, Accuracy: 0.6094
# Batch no: 102, Loss on trainig: 1.7610, Accuracy: 0.5417
# Epoch: 9/10
# Batch no: 000, Loss on trainig: 1.6355, Accuracy: 0.5469
# Batch no: 001, Loss on trainig: 1.1474, Accuracy: 0.6562
# Batch no: 002, Loss on trainig: 1.4633, Accuracy: 0.5625
# Batch no: 003, Loss on trainig: 1.7655, Accuracy: 0.5469
# Batch no: 004, Loss on trainig: 1.8177, Accuracy: 0.5469
# Batch no: 005, Loss on trainig: 1.5974, Accuracy: 0.6250
# Batch no: 006, Loss on trainig: 1.6900, Accuracy: 0.4844
# Batch no: 007, Loss on trainig: 1.5467, Accuracy: 0.5781
# Batch no: 008, Loss on trainig: 1.6246, Accuracy: 0.4688
# Batch no: 009, Loss on trainig: 1.5963, Accuracy: 0.5781
# Batch no: 010, Loss on trainig: 1.8450, Accuracy: 0.5156
# Batch no: 011, Loss on trainig: 1.5366, Accuracy: 0.6406
# Batch no: 012, Loss on trainig: 1.1067, Accuracy: 0.6875
# Batch no: 013, Loss on trainig: 1.6350, Accuracy: 0.5469
# Batch no: 014, Loss on trainig: 1.8150, Accuracy: 0.4844
# Batch no: 015, Loss on trainig: 1.6447, Accuracy: 0.5312
# Batch no: 016, Loss on trainig: 1.6750, Accuracy: 0.4844
# Batch no: 017, Loss on trainig: 1.6009, Accuracy: 0.5000
# Batch no: 018, Loss on trainig: 1.5564, Accuracy: 0.5781
# Batch no: 019, Loss on trainig: 1.9950, Accuracy: 0.5000
# Batch no: 020, Loss on trainig: 1.8399, Accuracy: 0.4844
# Batch no: 021, Loss on trainig: 1.0629, Accuracy: 0.7031
# Batch no: 022, Loss on trainig: 1.3941, Accuracy: 0.5938
# Batch no: 023, Loss on trainig: 1.7177, Accuracy: 0.5625
# Batch no: 024, Loss on trainig: 1.8971, Accuracy: 0.4375
# Batch no: 025, Loss on trainig: 1.9409, Accuracy: 0.5312
# Batch no: 026, Loss on trainig: 1.7198, Accuracy: 0.5625
# Batch no: 027, Loss on trainig: 1.7832, Accuracy: 0.5625
# Batch no: 028, Loss on trainig: 1.7881, Accuracy: 0.5469
# Batch no: 029, Loss on trainig: 1.7108, Accuracy: 0.5312
# Batch no: 030, Loss on trainig: 1.5691, Accuracy: 0.5156
# Batch no: 031, Loss on trainig: 1.4745, Accuracy: 0.6562
# Batch no: 032, Loss on trainig: 1.6189, Accuracy: 0.5781
# Batch no: 033, Loss on trainig: 1.8831, Accuracy: 0.4531
# Batch no: 034, Loss on trainig: 1.5045, Accuracy: 0.6094
# Batch no: 035, Loss on trainig: 1.4579, Accuracy: 0.5625
# Batch no: 036, Loss on trainig: 1.3665, Accuracy: 0.5625
# Batch no: 037, Loss on trainig: 2.0026, Accuracy: 0.4531
# Batch no: 038, Loss on trainig: 1.9823, Accuracy: 0.3906
# Batch no: 039, Loss on trainig: 2.1637, Accuracy: 0.4375
# Batch no: 040, Loss on trainig: 1.3885, Accuracy: 0.6562
# Batch no: 041, Loss on trainig: 1.5147, Accuracy: 0.5781
# Batch no: 042, Loss on trainig: 1.8911, Accuracy: 0.4688
# Batch no: 043, Loss on trainig: 1.3636, Accuracy: 0.6562
# Batch no: 044, Loss on trainig: 1.7336, Accuracy: 0.4844
# Batch no: 045, Loss on trainig: 1.5012, Accuracy: 0.5469
# Batch no: 046, Loss on trainig: 1.6033, Accuracy: 0.5469
# Batch no: 047, Loss on trainig: 1.3573, Accuracy: 0.6250
# Batch no: 048, Loss on trainig: 1.7533, Accuracy: 0.5156
# Batch no: 049, Loss on trainig: 1.4774, Accuracy: 0.5938
# Batch no: 050, Loss on trainig: 1.4547, Accuracy: 0.5312
# Batch no: 051, Loss on trainig: 1.4902, Accuracy: 0.5312
# Batch no: 052, Loss on trainig: 1.5479, Accuracy: 0.5469
# Batch no: 053, Loss on trainig: 1.4776, Accuracy: 0.6406
# Batch no: 054, Loss on trainig: 1.7480, Accuracy: 0.5000
# Batch no: 055, Loss on trainig: 1.5607, Accuracy: 0.5781
# Batch no: 056, Loss on trainig: 1.6913, Accuracy: 0.5781
# Batch no: 057, Loss on trainig: 1.5441, Accuracy: 0.5781
# Batch no: 058, Loss on trainig: 1.2927, Accuracy: 0.6094
# Batch no: 059, Loss on trainig: 1.4588, Accuracy: 0.5625
# Batch no: 060, Loss on trainig: 1.8075, Accuracy: 0.5000
# Batch no: 061, Loss on trainig: 1.0581, Accuracy: 0.6719
# Batch no: 062, Loss on trainig: 1.6408, Accuracy: 0.5156
# Batch no: 063, Loss on trainig: 1.3221, Accuracy: 0.6094
# Batch no: 064, Loss on trainig: 1.8525, Accuracy: 0.4531
# Batch no: 065, Loss on trainig: 1.7547, Accuracy: 0.5469
# Batch no: 066, Loss on trainig: 1.5041, Accuracy: 0.5469
# Batch no: 067, Loss on trainig: 1.6638, Accuracy: 0.5312
# Batch no: 068, Loss on trainig: 1.9080, Accuracy: 0.4844
# Batch no: 069, Loss on trainig: 1.2030, Accuracy: 0.6562
# Batch no: 070, Loss on trainig: 1.6505, Accuracy: 0.5625
# Batch no: 071, Loss on trainig: 1.6906, Accuracy: 0.5781
# Batch no: 072, Loss on trainig: 1.5898, Accuracy: 0.5625
# Batch no: 073, Loss on trainig: 1.4748, Accuracy: 0.5781
# Batch no: 074, Loss on trainig: 1.6457, Accuracy: 0.5156
# Batch no: 075, Loss on trainig: 1.7968, Accuracy: 0.4531
# Batch no: 076, Loss on trainig: 1.8058, Accuracy: 0.5000
# Batch no: 077, Loss on trainig: 1.7970, Accuracy: 0.5156
# Batch no: 078, Loss on trainig: 1.8413, Accuracy: 0.5469
# Batch no: 079, Loss on trainig: 1.7369, Accuracy: 0.5469
# Batch no: 080, Loss on trainig: 1.6522, Accuracy: 0.5312
# Batch no: 081, Loss on trainig: 1.8279, Accuracy: 0.4688
# Batch no: 082, Loss on trainig: 1.6845, Accuracy: 0.5781
# Batch no: 083, Loss on trainig: 1.5667, Accuracy: 0.5156
# Batch no: 084, Loss on trainig: 1.5620, Accuracy: 0.5312
# Batch no: 085, Loss on trainig: 1.4973, Accuracy: 0.6406
# Batch no: 086, Loss on trainig: 1.9445, Accuracy: 0.4844
# Batch no: 087, Loss on trainig: 1.4933, Accuracy: 0.5781
# Batch no: 088, Loss on trainig: 1.6014, Accuracy: 0.6094
# Batch no: 089, Loss on trainig: 1.4596, Accuracy: 0.5938
# Batch no: 090, Loss on trainig: 1.2958, Accuracy: 0.6719
# Batch no: 091, Loss on trainig: 1.7748, Accuracy: 0.5625
# Batch no: 092, Loss on trainig: 1.6511, Accuracy: 0.5625
# Batch no: 093, Loss on trainig: 1.8721, Accuracy: 0.4688
# Batch no: 094, Loss on trainig: 1.5099, Accuracy: 0.5000
# Batch no: 095, Loss on trainig: 1.8817, Accuracy: 0.5625
# Batch no: 096, Loss on trainig: 1.3381, Accuracy: 0.6562
# Batch no: 097, Loss on trainig: 1.3475, Accuracy: 0.6250
# Batch no: 098, Loss on trainig: 1.6477, Accuracy: 0.5625
# Batch no: 099, Loss on trainig: 1.9662, Accuracy: 0.4531
# Batch no: 100, Loss on trainig: 1.5633, Accuracy: 0.5156
# Batch no: 101, Loss on trainig: 2.0461, Accuracy: 0.5000
# Batch no: 102, Loss on trainig: 2.1013, Accuracy: 0.4167
# Epoch: 10/10
# Batch no: 000, Loss on trainig: 1.2384, Accuracy: 0.6562
# Batch no: 001, Loss on trainig: 1.3828, Accuracy: 0.6250
# Batch no: 002, Loss on trainig: 1.6091, Accuracy: 0.5469
# Batch no: 003, Loss on trainig: 1.5300, Accuracy: 0.4844
# Batch no: 004, Loss on trainig: 1.5820, Accuracy: 0.5156
# Batch no: 005, Loss on trainig: 1.6841, Accuracy: 0.5469
# Batch no: 006, Loss on trainig: 1.3468, Accuracy: 0.6406
# Batch no: 007, Loss on trainig: 1.7678, Accuracy: 0.5312
# Batch no: 008, Loss on trainig: 1.6137, Accuracy: 0.4844
# Batch no: 009, Loss on trainig: 1.5483, Accuracy: 0.5625
# Batch no: 010, Loss on trainig: 1.5829, Accuracy: 0.5625
# Batch no: 011, Loss on trainig: 1.6516, Accuracy: 0.5156
# Batch no: 012, Loss on trainig: 1.7876, Accuracy: 0.5625
# Batch no: 013, Loss on trainig: 1.5282, Accuracy: 0.5000
# Batch no: 014, Loss on trainig: 1.2899, Accuracy: 0.6406
# Batch no: 015, Loss on trainig: 1.4399, Accuracy: 0.5156
# Batch no: 016, Loss on trainig: 2.0197, Accuracy: 0.5156
# Batch no: 017, Loss on trainig: 1.6674, Accuracy: 0.4844
# Batch no: 018, Loss on trainig: 1.4820, Accuracy: 0.6094
# Batch no: 019, Loss on trainig: 1.8694, Accuracy: 0.4375
# Batch no: 020, Loss on trainig: 1.4377, Accuracy: 0.6406
# Batch no: 021, Loss on trainig: 1.5399, Accuracy: 0.6094
# Batch no: 022, Loss on trainig: 1.4153, Accuracy: 0.5938
# Batch no: 023, Loss on trainig: 1.8253, Accuracy: 0.5156
# Batch no: 024, Loss on trainig: 1.5667, Accuracy: 0.5469
# Batch no: 025, Loss on trainig: 1.2195, Accuracy: 0.6406
# Batch no: 026, Loss on trainig: 1.5385, Accuracy: 0.5938
# Batch no: 027, Loss on trainig: 1.6613, Accuracy: 0.5000
# Batch no: 028, Loss on trainig: 1.4104, Accuracy: 0.6562
# Batch no: 029, Loss on trainig: 1.4557, Accuracy: 0.5625
# Batch no: 030, Loss on trainig: 1.5888, Accuracy: 0.5625
# Batch no: 031, Loss on trainig: 1.6003, Accuracy: 0.5312
# Batch no: 032, Loss on trainig: 1.2962, Accuracy: 0.5781
# Batch no: 033, Loss on trainig: 1.6575, Accuracy: 0.5312
# Batch no: 034, Loss on trainig: 1.7304, Accuracy: 0.4688
# Batch no: 035, Loss on trainig: 1.5736, Accuracy: 0.6094
# Batch no: 036, Loss on trainig: 1.5489, Accuracy: 0.5625
# Batch no: 037, Loss on trainig: 1.7337, Accuracy: 0.5625
# Batch no: 038, Loss on trainig: 1.2708, Accuracy: 0.6406
# Batch no: 039, Loss on trainig: 1.5344, Accuracy: 0.5781
# Batch no: 040, Loss on trainig: 1.5739, Accuracy: 0.5625
# Batch no: 041, Loss on trainig: 1.3858, Accuracy: 0.5312
# Batch no: 042, Loss on trainig: 1.2958, Accuracy: 0.5625
# Batch no: 043, Loss on trainig: 1.5882, Accuracy: 0.5938
# Batch no: 044, Loss on trainig: 1.6332, Accuracy: 0.5312
# Batch no: 045, Loss on trainig: 2.3243, Accuracy: 0.4531
# Batch no: 046, Loss on trainig: 2.0795, Accuracy: 0.4688
# Batch no: 047, Loss on trainig: 1.2745, Accuracy: 0.5781
# Batch no: 048, Loss on trainig: 1.4679, Accuracy: 0.5781
# Batch no: 049, Loss on trainig: 1.3029, Accuracy: 0.5938
# Batch no: 050, Loss on trainig: 1.5837, Accuracy: 0.5469
# Batch no: 051, Loss on trainig: 1.7725, Accuracy: 0.5625
# Batch no: 052, Loss on trainig: 1.6010, Accuracy: 0.5781
# Batch no: 053, Loss on trainig: 1.5640, Accuracy: 0.6250
# Batch no: 054, Loss on trainig: 1.6507, Accuracy: 0.5469
# Batch no: 055, Loss on trainig: 1.4601, Accuracy: 0.6094
# Batch no: 056, Loss on trainig: 1.3975, Accuracy: 0.5625
# Batch no: 057, Loss on trainig: 1.3931, Accuracy: 0.5938
# Batch no: 058, Loss on trainig: 1.6186, Accuracy: 0.5625
# Batch no: 059, Loss on trainig: 1.8568, Accuracy: 0.4375
# Batch no: 060, Loss on trainig: 1.3109, Accuracy: 0.6562
# Batch no: 061, Loss on trainig: 1.6977, Accuracy: 0.5938
# Batch no: 062, Loss on trainig: 1.7604, Accuracy: 0.4531
# Batch no: 063, Loss on trainig: 1.3655, Accuracy: 0.5781
# Batch no: 064, Loss on trainig: 1.5519, Accuracy: 0.5469
# Batch no: 065, Loss on trainig: 1.6153, Accuracy: 0.5312
# Batch no: 066, Loss on trainig: 1.9387, Accuracy: 0.4688
# Batch no: 067, Loss on trainig: 1.2919, Accuracy: 0.6094
# Batch no: 068, Loss on trainig: 1.4548, Accuracy: 0.5469
# Batch no: 069, Loss on trainig: 1.6985, Accuracy: 0.5625
# Batch no: 070, Loss on trainig: 1.4604, Accuracy: 0.5781
# Batch no: 071, Loss on trainig: 1.1353, Accuracy: 0.6406
# Batch no: 072, Loss on trainig: 1.3464, Accuracy: 0.6406
# Batch no: 073, Loss on trainig: 1.9627, Accuracy: 0.5000
# Batch no: 074, Loss on trainig: 1.2047, Accuracy: 0.7500
# Batch no: 075, Loss on trainig: 1.5716, Accuracy: 0.5312
# Batch no: 076, Loss on trainig: 1.8414, Accuracy: 0.5000
# Batch no: 077, Loss on trainig: 1.8963, Accuracy: 0.4062
# Batch no: 078, Loss on trainig: 1.7907, Accuracy: 0.5469
# Batch no: 079, Loss on trainig: 1.5575, Accuracy: 0.5625
# Batch no: 080, Loss on trainig: 1.5521, Accuracy: 0.5312
# Batch no: 081, Loss on trainig: 1.4166, Accuracy: 0.6250
# Batch no: 082, Loss on trainig: 1.5739, Accuracy: 0.5938
# Batch no: 083, Loss on trainig: 1.5847, Accuracy: 0.4844
# Batch no: 084, Loss on trainig: 1.9403, Accuracy: 0.5469
# Batch no: 085, Loss on trainig: 1.1377, Accuracy: 0.6562
# Batch no: 086, Loss on trainig: 1.6127, Accuracy: 0.4688
# Batch no: 087, Loss on trainig: 1.4176, Accuracy: 0.5938
# Batch no: 088, Loss on trainig: 1.7650, Accuracy: 0.5312
# Batch no: 089, Loss on trainig: 1.6700, Accuracy: 0.6250
# Batch no: 090, Loss on trainig: 1.5843, Accuracy: 0.5000
# Batch no: 091, Loss on trainig: 1.4237, Accuracy: 0.5781
# Batch no: 092, Loss on trainig: 1.6502, Accuracy: 0.5156
# Batch no: 093, Loss on trainig: 1.2728, Accuracy: 0.6562
# Batch no: 094, Loss on trainig: 1.3875, Accuracy: 0.5781
# Batch no: 095, Loss on trainig: 1.5566, Accuracy: 0.5938
# Batch no: 096, Loss on trainig: 1.5184, Accuracy: 0.5781
# Batch no: 097, Loss on trainig: 1.4681, Accuracy: 0.5938
# Batch no: 098, Loss on trainig: 1.7861, Accuracy: 0.5625
# Batch no: 099, Loss on trainig: 1.2463, Accuracy: 0.6719
# Batch no: 100, Loss on trainig: 1.1557, Accuracy: 0.6562
# Batch no: 101, Loss on trainig: 1.4019, Accuracy: 0.5781
# Batch no: 102, Loss on trainig: 1.7279, Accuracy: 0.5417

# %% [markdown]
# ## Testing your network
#
# It's good practice to test your trained network on test data, images the network has never seen either in training or validation. This will give you a good estimate for the model's performance on completely new images. Run the test images through the network and measure the accuracy, the same way you did validation. You should be able to reach around 70% accuracy on the test set if the model has been trained well.

# %%
# TODO: Do validation on the test set
#Maintaining a separate validation set is important, 
#so that we can stop the training at the right point and prevent overfitting. 
#Validation is carried out in each epoch immediately after the training loop.
#Since we do not need any gradient computation in the validation process, it is done with torch.no_grad().
#For each validation batch, the inputs and labels are transferred to the GPU ( if cuda is available, else cpu).
#The inputs go through the forwards pass, 
#followed by the loss and accuracy computations for the batch and at the end of the loop, for the whole epoch.

# Validation - No gradient tracking needed
with torch.no_grad():
 
    # Set to evaluation mode
    model.eval()


    # Validation loop
    for j, (inputs, labels) in enumerate(validation_loader):
        inputs = inputs.to('cuda')
        labels = labels.to('cuda')
 
        # Forward pass - compute outputs on input data using the model
        outputs = model(inputs)
 
        # Compute loss
        loss = criterion(outputs, labels)
 
        # Compute the total loss for the batch and add it to valid_loss
        valid_loss += loss.item() * inputs.size(0)
 
        # Calculate validation accuracy
        ret, predictions = torch.max(outputs.data, 1)
        correct_counts = predictions.eq(labels.data.view_as(predictions))
 
        # Convert correct_counts to float and then compute the mean
        acc = torch.mean(correct_counts.type(torch.FloatTensor))
 
        # Compute total accuracy in the whole batch and add to valid_acc
        valid_acc += acc.item() * inputs.size(0)
 
        print("Validation Batch number: {:03d}, Validation: Loss: {:.4f}, Accuracy: {:.4f}".format(j, loss.item(), acc.item()))
# Out:
# Validation Batch number: 000, Validation: Loss: 0.6865, Accuracy: 0.8281
# Validation Batch number: 001, Validation: Loss: 0.7783, Accuracy: 0.7656
# Validation Batch number: 002, Validation: Loss: 0.7608, Accuracy: 0.7812
# Validation Batch number: 003, Validation: Loss: 0.8167, Accuracy: 0.8438
# Validation Batch number: 004, Validation: Loss: 0.7222, Accuracy: 0.7656
# Validation Batch number: 005, Validation: Loss: 0.7565, Accuracy: 0.7812
# Validation Batch number: 006, Validation: Loss: 0.6255, Accuracy: 0.8594
# Validation Batch number: 007, Validation: Loss: 0.6829, Accuracy: 0.7812
# Validation Batch number: 008, Validation: Loss: 0.9831, Accuracy: 0.7344
# Validation Batch number: 009, Validation: Loss: 0.8065, Accuracy: 0.7969
# Validation Batch number: 010, Validation: Loss: 0.9534, Accuracy: 0.7031
# Validation Batch number: 011, Validation: Loss: 0.5567, Accuracy: 0.8438
# Validation Batch number: 012, Validation: Loss: 0.6277, Accuracy: 0.8400

# %% [markdown]
# ## Save the checkpoint
#
# Now that your network is trained, save the model so you can load it later for making predictions. You probably want to save other things such as the mapping of classes to indices which you get from one of the image datasets: `image_datasets['train'].class_to_idx`. You can attach this to the model as an attribute which makes inference easier later on.
#
# ```model.class_to_idx = image_datasets['train'].class_to_idx```
#
# Remember that you'll want to completely rebuild the model later so you can use it for inference. Make sure to include any information you need in the checkpoint. If you want to load the model and keep training, you'll want to save the number of epochs as well as the optimizer state, `optimizer.state_dict`. You'll likely want to use this trained model in the next part of the project, so best to save it now.

# %%
# TODO: Save the checkpoint 
model.class_to_idx = image_datasets['train'].class_to_idx
torch.save({'structure' :'alexnet',
            'hidden_layer1':120,
             'droupout':0.5,
             'epochs':10,
             'state_dict':model.state_dict(),
             'class_to_idx':model.class_to_idx,
             'optimizer_dict':optimizer.state_dict()},
             'checkpoint.pth')

# %% [markdown]
# ## Loading the checkpoint
#
# At this point it's good to write a function that can load a checkpoint and rebuild the model. That way you can come back to this project and keep working on it without having to retrain the network.

# %%
# TODO: Write a function that loads a checkpoint and rebuilds the model
def loading_the_checkpoint(path='checkpoint.pth'):
    #load the saved file
    checkpoint = torch.load('checkpoint.pth')
    #download pretrained model
    model=models.vgg16(pretrained=True)
    #to freeze parameters
    for param in model.parameters():
        param.requires_grad = False
    #load from checkpoint
    model.class_to_idx = checkpoint['class_to_idx']
    model.load_state_dict(checkpoint['state_dict'])
    return model

# %% [markdown]
# # Inference for classification
#
# Now you'll write a function to use a trained network for inference. That is, you'll pass an image into the network and predict the class of the flower in the image. Write a function called `predict` that takes an image and a model, then returns the top $K$ most likely classes along with the probabilities. It should look like
#
# ```python
# probs, classes = predict(image_path, model)
# print(probs)
# print(classes)
# > [ 0.01558163  0.01541934  0.01452626  0.01443549  0.01407339]
# > ['70', '3', '45', '62', '55']
# ```
#
# First you'll need to handle processing the input image such that it can be used in your network.
#
# ## Image Preprocessing
#
# You'll want to use `PIL` to load the image ([documentation](https://pillow.readthedocs.io/en/latest/reference/Image.html)). It's best to write a function that preprocesses the image so it can be used as input for the model. This function should process the images in the same manner used for training.
#
# First, resize the images where the shortest side is 256 pixels, keeping the aspect ratio. This can be done with the [`thumbnail`](http://pillow.readthedocs.io/en/3.1.x/reference/Image.html#PIL.Image.Image.thumbnail) or [`resize`](http://pillow.readthedocs.io/en/3.1.x/reference/Image.html#PIL.Image.Image.thumbnail) methods. Then you'll need to crop out the center 224x224 portion of the image.
#
# Color channels of images are typically encoded as integers 0-255, but the model expected floats 0-1. You'll need to convert the values. It's easiest with a Numpy array, which you can get from a PIL image like so `np_image = np.array(pil_image)`.
#
# As before, the network expects the images to be normalized in a specific way. For the means, it's `[0.485, 0.456, 0.406]` and for the standard deviations `[0.229, 0.224, 0.225]`. You'll want to subtract the means from each color channel, then divide by the standard deviation.
#
# And finally, PyTorch expects the color channel to be the first dimension but it's the third dimension in the PIL image and Numpy array. You can reorder dimensions using [`ndarray.transpose`](https://docs.scipy.org/doc/numpy-1.13.0/reference/generated/numpy.ndarray.transpose.html). The color channel needs to be first and retain the order of the other two dimensions.

# %%
def process_image(image):
    ''' Scales, crops, and normalizes a PIL image for a PyTorch model,
        returns an Numpy array
    '''

def process_image(image):
    ''' Scales, crops, and normalizes a PIL image for a PyTorch model,
        returns an Numpy array
    '''

    img = PIL.Image.open(image)

    # Get original dimensions
    original_width, original_height = img.size

    # Find shorter size and create settings to crop shortest side to 256
    if original_width < original_height:
        size=[256, 256**600]
    else: 
        size=[256**600, 256]
        
    img.thumbnail(size)
   

    center = original_width/4, original_height/4
    left, top, right, bottom = center[0]-(244/2), center[1]-(244/2), center[0]+(244/2), center[1]+(244/2)
    img = img.crop((left, top, right, bottom))

    numpy_img = np.array(img)/255 

    # Normalize each color channel
    mean = [0.485, 0.456, 0.406]
    std = [0.229, 0.224, 0.225]
    numpy_img = (numpy_img-mean)/std
        
    # Set the color to the first channel
    numpy_img = numpy_img.transpose(2, 0, 1)
    
    return numpy_img

# %% [markdown]
# To check your work, the function below converts a PyTorch tensor and displays it in the notebook. If your `process_image` function works, running the output through this function should return the original image (except for the cropped out portions).

# %%
def imshow(image, ax=None, title=None):
    #img for tensor
    if ax is None:
        fig, ax = plt.subplots()
    
    # PyTorch tensors assume the color channel is the first dimension
    # but matplotlib assumes is the third dimension
    image = image.transpose((1, 2, 0))   
    # Undo preprocessing
    mean = np.array([0.485, 0.456, 0.406])
    std = np.array([0.229, 0.224, 0.225])
    image = std * image + mean
    
    # Image needs to be clipped between 0 and 1 or it looks like noise when displayed
    image = np.clip(image, 0, 1)
    
    ax.imshow(image)
    
    return ax

imshow(process_image("flowers/test/15/image_06360.jpg"))

# %% [markdown]
# ## Class Prediction
#
# Once you can get images in the correct format, it's time to write a function for making predictions with your model. A common practice is to predict the top 5 or so (usually called top-$K$) most probable classes. You'll want to calculate the class probabilities then find the $K$ largest values.
#
# To get the top $K$ largest values in a tensor use [`x.topk(k)`](http://pytorch.org/docs/master/torch.html#torch.topk). This method returns both the highest `k` probabilities and the indices of those probabilities corresponding to the classes. You need to convert from these indices to the actual class labels using `class_to_idx` which hopefully you added to the model or from an `ImageFolder` you used to load the data ([see here](#Save-the-checkpoint)). Make sure to invert the dictionary so you get a mapping from index to class as well.
#
# Again, this method should take a path to an image and a model checkpoint, then return the probabilities and classes.
#
# ```python
# probs, classes = predict(image_path, model)
# print(probs)
# print(classes)
# > [ 0.01558163  0.01541934  0.01452626  0.01443549  0.01407339]
# > ['70', '3', '45', '62', '55']
# ```

# %%
def predict(image_path, model, top_k=5):
    ''' Predict the class (or classes) of an image using a trained deep learning model.
    
    image_path: string. Path to image, directly to image and not to folder.
    model: pytorch neural network.
    top_k: integer. The top K classes to be calculated
    
    returns top_probabilities(k), top_labels
    '''
    
    # No need for GPU on this part (just causes problems)
    model.to("cpu")
    
    # Set model to evaluate
    model.eval();

    # Convert image from numpy to torch
    torch_image = torch.from_numpy(np.expand_dims(process_image(image_path), 
                                                  axis=0)).type(torch.FloatTensor).to("cpu")

    # Find probabilities (results) by passing through the function (note the log softmax means that its on a log scale)
    log_probs = model.forward(torch_image)

    # Convert to linear scale
    linear_probs = torch.exp(log_probs)

    # Find the top 5 results
    top_probs, top_labels = linear_probs.topk(top_k)
    
    # Detatch all of the details
    top_probs = np.array(top_probs.detach())[0] # This is not the correct way to do it but the correct way isnt working thanks to cpu/gpu issues so I don't care.
    top_labels = np.array(top_labels.detach())[0]
    
    # Convert to classes
    idx_to_class = {val: key for key, val in    
                                      model.class_to_idx.items()}
    top_labels = [idx_to_class[lab] for lab in top_labels]
    top_flowers = [cat_to_name[lab] for lab in top_labels]
    
    return top_probs, top_labels, top_flowers

# %% [markdown]
# ## Sanity Checking
#
# Now that you can use a trained model for predictions, check to make sure it makes sense. Even if the testing accuracy is high, it's always good to check that there aren't obvious bugs. Use `matplotlib` to plot the probabilities for the top 5 classes as a bar graph, along with the input image. It should look like this:
#
# <img src='assets/inference_example.png' width=300px>
#
# You can convert from the class integer encoding to actual flower names with the `cat_to_name.json` file (should have been loaded earlier in the notebook). To show a PyTorch tensor as an image, use the `imshow` function defined above.

# %%
# TODO: Display an image along with the top 5 classes
# Define image path
image_path = "flowers/test/15/image_06369.jpg"

# Set up plot
plt.figure(figsize = (6,10))
ax = plt.subplot(2,1,1)

# Set up title
flower_num = image_path.split('/')[2]
title_ = cat_to_name[flower_num]

# Plot flower
img = process_image(image_path)
imshow(img, ax, title = title_);

# Make prediction
probs, labs, flowers = predict(image_path, model) 

# Plot bar chart
plt.subplot(2,1,2)
sns.barplot(x=probs, y=flowers, color=sns.color_palette()[0]);
plt.show()

# %% [markdown]
# <font color='red'>**Reminder for Workspace users:** If your network becomes very large when saved as a checkpoint, there might be issues with saving backups in your workspace. You should reduce the size of your hidden layers and train again.
#
# We strongly encourage you to delete these large interim files and directories before navigating to another page or closing the browser tab.</font>

# %%
# TODO remove .pth files or move it to a temporary `~/opt` directory in this Workspace
